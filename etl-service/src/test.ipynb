# %%
import psycopg2
import pandas as pd
from utils.utils import get_postgres_connection


def read_financial_metrics():
    """Simple function to read financial_metrics table and return as pandas DataFrame"""
    conn = get_postgres_connection()
    query = "SELECT * FROM raw.financial_metrics"
    df = pd.read_sql_query(query, conn)
    conn.close()
    return df


df = read_financial_metrics()
print(f"Read {len(df)} records from financial_metrics table")
print(df.head())
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x1079a5490>>
# Traceback (most recent call last):
#   File "/Users/aleksamihajlovic/Documents/naro-index-advisor/etl-service/.venv/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 781, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:

# %%
df.columns
# Out:
# Index(['symbol', 'date', 'fiscal_year', 'period', 'reported_currency',
#        'gross_profit_margin', 'ebit_margin', 'ebitda_margin',
#        'operating_profit_margin', 'pretax_profit_margin',
#        'continuous_operations_profit_margin', 'net_profit_margin',
#        'bottom_line_profit_margin', 'current_ratio', 'quick_ratio',
#        'solvency_ratio', 'cash_ratio', 'receivables_turnover',
#        'payables_turnover', 'inventory_turnover', 'fixed_asset_turnover',
#        'asset_turnover', 'working_capital_turnover_ratio',
#        'price_to_earnings_ratio', 'price_to_earnings_growth_ratio',
#        'forward_price_to_earnings_growth_ratio', 'price_to_book_ratio',
#        'price_to_sales_ratio', 'price_to_free_cash_flow_ratio',
#        'price_to_operating_cash_flow_ratio', 'price_to_fair_value',
#        'debt_to_assets_ratio', 'debt_to_equity_ratio', 'debt_to_capital_ratio',
#        'long_term_debt_to_capital_ratio', 'financial_leverage_ratio',
#        'debt_to_market_cap', 'operating_cash_flow_ratio',
#        'operating_cash_flow_sales_ratio',
#        'free_cash_flow_operating_cash_flow_ratio',
#        'debt_service_coverage_ratio', 'interest_coverage_ratio',
#        'short_term_operating_cash_flow_coverage_ratio',
#        'operating_cash_flow_coverage_ratio',
#        'capital_expenditure_coverage_ratio',
#        'dividend_paid_and_capex_coverage_ratio', 'dividend_payout_ratio',
#        'dividend_yield', 'dividend_yield_percentage', 'dividend_per_share',
#        'revenue_per_share', 'net_income_per_share', 'interest_debt_per_share',
#        'cash_per_share', 'book_value_per_share',
#        'tangible_book_value_per_share', 'shareholders_equity_per_share',
#        'operating_cash_flow_per_share', 'capex_per_share',
#        'free_cash_flow_per_share', 'net_income_per_ebt', 'ebt_per_ebit',
#        'effective_tax_rate', 'enterprise_value_multiple', 'created_at',
#        'percentile_bucket'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
from IPython.display import display_html

def _safe_numeric_series(s: pd.Series) -> pd.Series:
    """Keep only finite numeric values."""
    s = pd.to_numeric(s, errors="coerce")
    s = s.replace([np.inf, -np.inf], np.nan).dropna()
    return s

def _summary_with_custom_percentiles(s: pd.Series, percentiles=None) -> pd.DataFrame:
    if percentiles is None:
        # include 5th, 95th and deciles 10..90
        percentiles = [0.001, 0.01,0.05] + [i/100 for i in range(10, 100, 10)] + [0.95, 0.99, 0.999]
    desc = s.describe(percentiles=percentiles)
    out = desc.reset_index()
    out.columns = ["Statistic", "Value"]
    return out

def _bucket_counts_qcut(s: pd.Series, q=10) -> pd.DataFrame:
    """Counts per percentile bucket, safe against duplicates and constants."""
    n = len(s)
    if n == 0:
        return pd.DataFrame({"Percentile Bucket": [], "Count": []})
    if s.nunique(dropna=True) < 2:
        return pd.DataFrame({"Percentile Bucket": ["All values equal"], "Count": [n]})

    try:
        buckets = pd.qcut(s, q=q, labels=[f"{i*100//q}-{(i+1)*100//q}%" for i in range(q)], duplicates="drop")
        counts = buckets.value_counts().sort_index().reset_index()
        counts.columns = ["Percentile Bucket", "Count"]
        return counts
    except Exception:
        qs = np.linspace(0, 1, q + 1)
        edges = np.unique(s.quantile(qs).values)
        if len(edges) < 2:
            return pd.DataFrame({"Percentile Bucket": ["All values equal"], "Count": [n]})
        labels = [f"{int(qs[i]*100)}-{int(qs[i+1]*100)}%" for i in range(len(edges)-1)]
        buckets = pd.cut(s, bins=edges, include_lowest=True, labels=labels, duplicates="drop")
        counts = buckets.value_counts().sort_index().reset_index()
        counts.columns = ["Percentile Bucket", "Count"]
        return counts

def _display_side_by_side(dfs: list, titles: list):
    html = ""
    for df, title in zip(dfs, titles):
        html += (
            "<div style='display:inline-block; padding-right:30px; vertical-align:top;'>"
            f"<h3 style='margin:4px 0 8px 0;'>{title}</h3>"
            f"{df.to_html(index=False)}"
            "</div>"
        )
    display_html(html, raw=True)

def describe_all_numeric_with_buckets(df: pd.DataFrame, q=10, percentiles=None, max_cols=None):
    """
    For each numeric column:
      - show summary with custom percentiles (5th, 10..90, 95th by default)
      - show counts per percentile bucket
    """
    num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    if max_cols is not None:
        num_cols = num_cols[:max_cols]

    if not num_cols:
        print("No numeric columns found.")
        return

    for col in num_cols:
        s = _safe_numeric_series(df[col])
        if s.empty:
            print(f"📭 Column: {col} — skipped (no finite numeric values).")
            continue

        stats = _summary_with_custom_percentiles(s, percentiles=percentiles)
        buckets = _bucket_counts_qcut(s, q=q)

        print(f"📊 Column: {col} (n={len(s)})")
        _display_side_by_side(
            [stats, buckets],
            ["Summary Statistics", f"Counts per Percentile Bucket ({q} buckets)"]
        )
        print()  # spacing


# ---- Run it ----
# This will include 5th, 10..90, 95th percentiles + decile bucket counts
describe_all_numeric_with_buckets(df, q=10)
# Out:
# 📊 Column: gross_profit_margin (n=1557417)
# <div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Summary Statistics</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Statistic</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>count</td>
#       <td>1557417.000000</td>
#     </tr>
#     <tr>
#       <td>mean</td>
#       <td>-2436.884422</td>
#     </tr>
#     <tr>
#       <td>std</td>
#       <td>2346429.840695</td>
#     </tr>
#     <tr>
#       <td>min</td>
#       <td>-2882786194.286195</td>
#     </tr>
#     <tr>
#       <td>0.1%</td>
#       <td>-138.667394</td>
#     </tr>
#     <tr>
#       <td>1%</td>
#       <td>-1.857993</td>
#     </tr>
#     <tr>
#       <td>5%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>10%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>20%</td>
#       <td>0.077175</td>
#     </tr>
#     <tr>
#       <td>30%</td>
#       <td>0.157231</td>
#     </tr>
#     <tr>
#       <td>40%</td>
#       <td>0.222949</td>
#     </tr>
#     <tr>
#       <td>50%</td>
#       <td>0.291742</td>
#     </tr>
#     <tr>
#       <td>60%</td>
#       <td>0.373303</td>
#     </tr>
#     <tr>
#       <td>70%</td>
#       <td>0.483576</td>
#     </tr>
#     <tr>
#       <td>80%</td>
#       <td>0.647983</td>
#     </tr>
#     <tr>
#       <td>90%</td>
#       <td>0.938596</td>
#     </tr>
#     <tr>
#       <td>95%</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>99%</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>99.9%</td>
#       <td>7.458629</td>
#     </tr>
#     <tr>
#       <td>max</td>
#       <td>61481897.100000</td>
#     </tr>
#   </tbody>
# </table></div><div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Counts per Percentile Bucket (10 buckets)</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percentile Bucket</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0-10%</td>
#       <td>237794</td>
#     </tr>
#     <tr>
#       <td>10-20%</td>
#       <td>73692</td>
#     </tr>
#     <tr>
#       <td>20-30%</td>
#       <td>155742</td>
#     </tr>
#     <tr>
#       <td>30-40%</td>
#       <td>155740</td>
#     </tr>
#     <tr>
#       <td>40-50%</td>
#       <td>155743</td>
#     </tr>
#     <tr>
#       <td>50-60%</td>
#       <td>155740</td>
#     </tr>
#     <tr>
#       <td>60-70%</td>
#       <td>155741</td>
#     </tr>
#     <tr>
#       <td>70-80%</td>
#       <td>155741</td>
#     </tr>
#     <tr>
#       <td>80-90%</td>
#       <td>155743</td>
#     </tr>
#     <tr>
#       <td>90-100%</td>
#       <td>155741</td>
#     </tr>
#   </tbody>
# </table></div>
# 📊 Column: ebit_margin (n=1557413)
# <div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Summary Statistics</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Statistic</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>count</td>
#       <td>1557413.000000</td>
#     </tr>
#     <tr>
#       <td>mean</td>
#       <td>-5928.403458</td>
#     </tr>
#     <tr>
#       <td>std</td>
#       <td>4323168.063856</td>
#     </tr>
#     <tr>
#       <td>min</td>
#       <td>-3882786195.286195</td>
#     </tr>
#     <tr>
#       <td>0.1%</td>
#       <td>-4999.881298</td>
#     </tr>
#     <tr>
#       <td>1%</td>
#       <td>-56.557902</td>
#     </tr>
#     <tr>
#       <td>5%</td>
#       <td>-1.692778</td>
#     </tr>
#     <tr>
#       <td>10%</td>
#       <td>-0.313041</td>
#     </tr>
#     <tr>
#       <td>20%</td>
#       <td>-0.018701</td>
#     </tr>
#     <tr>
#       <td>30%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>40%</td>
#       <td>0.021365</td>
#     </tr>
#     <tr>
#       <td>50%</td>
#       <td>0.053137</td>
#     </tr>
#     <tr>
#       <td>60%</td>
#       <td>0.086421</td>
#     </tr>
#     <tr>
#       <td>70%</td>
#       <td>0.129837</td>
#     </tr>
#     <tr>
#       <td>80%</td>
#       <td>0.197904</td>
#     </tr>
#     <tr>
#       <td>90%</td>
#       <td>0.354108</td>
#     </tr>
#     <tr>
#       <td>95%</td>
#       <td>0.603044</td>
#     </tr>
#     <tr>
#       <td>99%</td>
#       <td>2.204439</td>
#     </tr>
#     <tr>
#       <td>99.9%</td>
#       <td>226.335114</td>
#     </tr>
#     <tr>
#       <td>max</td>
#       <td>1208474000.000000</td>
#     </tr>
#   </tbody>
# </table></div><div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Counts per Percentile Bucket (10 buckets)</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percentile Bucket</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0-10%</td>
#       <td>155742</td>
#     </tr>
#     <tr>
#       <td>10-20%</td>
#       <td>155741</td>
#     </tr>
#     <tr>
#       <td>20-30%</td>
#       <td>234193</td>
#     </tr>
#     <tr>
#       <td>30-40%</td>
#       <td>77291</td>
#     </tr>
#     <tr>
#       <td>40-50%</td>
#       <td>155745</td>
#     </tr>
#     <tr>
#       <td>50-60%</td>
#       <td>155740</td>
#     </tr>
#     <tr>
#       <td>60-70%</td>
#       <td>155741</td>
#     </tr>
#     <tr>
#       <td>70-80%</td>
#       <td>155737</td>
#     </tr>
#     <tr>
#       <td>80-90%</td>
#       <td>155741</td>
#     </tr>
#     <tr>
#       <td>90-100%</td>
#       <td>155742</td>
#     </tr>
#   </tbody>
# </table></div>
# 📊 Column: ebitda_margin (n=1557391)
# <div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Summary Statistics</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Statistic</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>count</td>
#       <td>1557391.000000</td>
#     </tr>
#     <tr>
#       <td>mean</td>
#       <td>-10296.144125</td>
#     </tr>
#     <tr>
#       <td>std</td>
#       <td>5284908.535616</td>
#     </tr>
#     <tr>
#       <td>min</td>
#       <td>-3831439393.939394</td>
#     </tr>
#     <tr>
#       <td>0.1%</td>
#       <td>-4030.853036</td>
#     </tr>
#     <tr>
#       <td>1%</td>
#       <td>-52.807521</td>
#     </tr>
#     <tr>
#       <td>5%</td>
#       <td>-1.531197</td>
#     </tr>
#     <tr>
#       <td>10%</td>
#       <td>-0.236546</td>
#     </tr>
#     <tr>
#       <td>20%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>30%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>40%</td>
#       <td>0.046761</td>
#     </tr>
#     <tr>
#       <td>50%</td>
#       <td>0.083651</td>
#     </tr>
#     <tr>
#       <td>60%</td>
#       <td>0.122808</td>
#     </tr>
#     <tr>
#       <td>70%</td>
#       <td>0.172151</td>
#     </tr>
#     <tr>
#       <td>80%</td>
#       <td>0.248753</td>
#     </tr>
#     <tr>
#       <td>90%</td>
#       <td>0.412161</td>
#     </tr>
#     <tr>
#       <td>95%</td>
#       <td>0.631265</td>
#     </tr>
#     <tr>
#       <td>99%</td>
#       <td>2.075216</td>
#     </tr>
#     <tr>
#       <td>99.9%</td>
#       <td>221.344090</td>
#     </tr>
#     <tr>
#       <td>max</td>
#       <td>1205561000.000000</td>
#     </tr>
#   </tbody>
# </table></div><div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Counts per Percentile Bucket (10 buckets)</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percentile Bucket</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0-10%</td>
#       <td>155740</td>
#     </tr>
#     <tr>
#       <td>10-20%</td>
#       <td>321318</td>
#     </tr>
#     <tr>
#       <td>20-30%</td>
#       <td>145900</td>
#     </tr>
#     <tr>
#       <td>30-40%</td>
#       <td>155738</td>
#     </tr>
#     <tr>
#       <td>40-50%</td>
#       <td>155741</td>
#     </tr>
#     <tr>
#       <td>50-60%</td>
#       <td>155739</td>
#     </tr>
#     <tr>
#       <td>60-70%</td>
#       <td>155737</td>
#     </tr>
#     <tr>
#       <td>70-80%</td>
#       <td>155739</td>
#     </tr>
#     <tr>
#       <td>80-90%</td>
#       <td>155739</td>
#     </tr>
#   </tbody>
# </table></div>
# 📊 Column: operating_profit_margin (n=1557411)
# <div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Summary Statistics</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Statistic</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>count</td>
#       <td>1557411.000000</td>
#     </tr>
#     <tr>
#       <td>mean</td>
#       <td>-8668.794156</td>
#     </tr>
#     <tr>
#       <td>std</td>
#       <td>5157820.355513</td>
#     </tr>
#     <tr>
#       <td>min</td>
#       <td>-3882786195.286195</td>
#     </tr>
#     <tr>
#       <td>0.1%</td>
#       <td>-3294.598110</td>
#     </tr>
#     <tr>
#       <td>1%</td>
#       <td>-57.290839</td>
#     </tr>
#     <tr>
#       <td>5%</td>
#       <td>-1.817782</td>
#     </tr>
#     <tr>
#       <td>10%</td>
#       <td>-0.342389</td>
#     </tr>
#     <tr>
#       <td>20%</td>
#       <td>-0.025445</td>
#     </tr>
#     <tr>
#       <td>30%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>40%</td>
#       <td>0.021969</td>
#     </tr>
#     <tr>
#       <td>50%</td>
#       <td>0.051897</td>
#     </tr>
#     <tr>
#       <td>60%</td>
#       <td>0.084422</td>
#     </tr>
#     <tr>
#       <td>70%</td>
#       <td>0.127464</td>
#     </tr>
#     <tr>
#       <td>80%</td>
#       <td>0.195418</td>
#     </tr>
#     <tr>
#       <td>90%</td>
#       <td>0.352697</td>
#     </tr>
#     <tr>
#       <td>95%</td>
#       <td>0.588356</td>
#     </tr>
#     <tr>
#       <td>99%</td>
#       <td>1.582735</td>
#     </tr>
#     <tr>
#       <td>99.9%</td>
#       <td>117.634054</td>
#     </tr>
#     <tr>
#       <td>max</td>
#       <td>1209580000.000000</td>
#     </tr>
#   </tbody>
# </table></div><div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Counts per Percentile Bucket (10 buckets)</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percentile Bucket</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0-10%</td>
#       <td>155742</td>
#     </tr>
#     <tr>
#       <td>10-20%</td>
#       <td>155741</td>
#     </tr>
#     <tr>
#       <td>20-30%</td>
#       <td>218658</td>
#     </tr>
#     <tr>
#       <td>30-40%</td>
#       <td>92824</td>
#     </tr>
#     <tr>
#       <td>40-50%</td>
#       <td>155742</td>
#     </tr>
#     <tr>
#       <td>50-60%</td>
#       <td>155741</td>
#     </tr>
#     <tr>
#       <td>60-70%</td>
#       <td>155740</td>
#     </tr>
#     <tr>
#       <td>70-80%</td>
#       <td>155742</td>
#     </tr>
#     <tr>
#       <td>80-90%</td>
#       <td>155740</td>
#     </tr>
#     <tr>
#       <td>90-100%</td>
#       <td>155741</td>
#     </tr>
#   </tbody>
# </table></div>
# 📊 Column: pretax_profit_margin (n=1557219)
# <div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Summary Statistics</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Statistic</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>count</td>
#       <td>1557219.000000</td>
#     </tr>
#     <tr>
#       <td>mean</td>
#       <td>-6904.814862</td>
#     </tr>
#     <tr>
#       <td>std</td>
#       <td>4552043.429496</td>
#     </tr>
#     <tr>
#       <td>min</td>
#       <td>-3855218855.218855</td>
#     </tr>
#     <tr>
#       <td>0.1%</td>
#       <td>-3887.460469</td>
#     </tr>
#     <tr>
#       <td>1%</td>
#       <td>-63.736630</td>
#     </tr>
#     <tr>
#       <td>5%</td>
#       <td>-2.066390</td>
#     </tr>
#     <tr>
#       <td>10%</td>
#       <td>-0.412338</td>
#     </tr>
#     <tr>
#       <td>20%</td>
#       <td>-0.042140</td>
#     </tr>
#     <tr>
#       <td>30%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>40%</td>
#       <td>0.014368</td>
#     </tr>
#     <tr>
#       <td>50%</td>
#       <td>0.044237</td>
#     </tr>
#     <tr>
#       <td>60%</td>
#       <td>0.076599</td>
#     </tr>
#     <tr>
#       <td>70%</td>
#       <td>0.118820</td>
#     </tr>
#     <tr>
#       <td>80%</td>
#       <td>0.184789</td>
#     </tr>
#     <tr>
#       <td>90%</td>
#       <td>0.332224</td>
#     </tr>
#     <tr>
#       <td>95%</td>
#       <td>0.540885</td>
#     </tr>
#     <tr>
#       <td>99%</td>
#       <td>2.404925</td>
#     </tr>
#     <tr>
#       <td>99.9%</td>
#       <td>251.399803</td>
#     </tr>
#     <tr>
#       <td>max</td>
#       <td>1208477000.000000</td>
#     </tr>
#   </tbody>
# </table></div><div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Counts per Percentile Bucket (10 buckets)</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percentile Bucket</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0-10%</td>
#       <td>155722</td>
#     </tr>
#     <tr>
#       <td>10-20%</td>
#       <td>155722</td>
#     </tr>
#     <tr>
#       <td>20-30%</td>
#       <td>246033</td>
#     </tr>
#     <tr>
#       <td>30-40%</td>
#       <td>65418</td>
#     </tr>
#     <tr>
#       <td>40-50%</td>
#       <td>155716</td>
#     </tr>
#     <tr>
#       <td>50-60%</td>
#       <td>155722</td>
#     </tr>
#     <tr>
#       <td>60-70%</td>
#       <td>155721</td>
#     </tr>
#     <tr>
#       <td>70-80%</td>
#       <td>155723</td>
#     </tr>
#     <tr>
#       <td>80-90%</td>
#       <td>155720</td>
#     </tr>
#     <tr>
#       <td>90-100%</td>
#       <td>155722</td>
#     </tr>
#   </tbody>
# </table></div>
# 📊 Column: continuous_operations_profit_margin (n=1557409)
# <div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Summary Statistics</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Statistic</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>count</td>
#       <td>1557409.000000</td>
#     </tr>
#     <tr>
#       <td>mean</td>
#       <td>-7271.985768</td>
#     </tr>
#     <tr>
#       <td>std</td>
#       <td>4571794.229289</td>
#     </tr>
#     <tr>
#       <td>min</td>
#       <td>-3855218855.218855</td>
#     </tr>
#     <tr>
#       <td>0.1%</td>
#       <td>-5285.960918</td>
#     </tr>
#     <tr>
#       <td>1%</td>
#       <td>-64.222625</td>
#     </tr>
#     <tr>
#       <td>5%</td>
#       <td>-1.978887</td>
#     </tr>
#     <tr>
#       <td>10%</td>
#       <td>-0.392443</td>
#     </tr>
#     <tr>
#       <td>20%</td>
#       <td>-0.040382</td>
#     </tr>
#     <tr>
#       <td>30%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>40%</td>
#       <td>0.008743</td>
#     </tr>
#     <tr>
#       <td>50%</td>
#       <td>0.032496</td>
#     </tr>
#     <tr>
#       <td>60%</td>
#       <td>0.058539</td>
#     </tr>
#     <tr>
#       <td>70%</td>
#       <td>0.092885</td>
#     </tr>
#     <tr>
#       <td>80%</td>
#       <td>0.147435</td>
#     </tr>
#     <tr>
#       <td>90%</td>
#       <td>0.271315</td>
#     </tr>
#     <tr>
#       <td>95%</td>
#       <td>0.466676</td>
#     </tr>
#     <tr>
#       <td>99%</td>
#       <td>2.410459</td>
#     </tr>
#     <tr>
#       <td>99.9%</td>
#       <td>286.882821</td>
#     </tr>
#     <tr>
#       <td>max</td>
#       <td>1208477000.000000</td>
#     </tr>
#   </tbody>
# </table></div><div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Counts per Percentile Bucket (10 buckets)</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percentile Bucket</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0-10%</td>
#       <td>155741</td>
#     </tr>
#     <tr>
#       <td>10-20%</td>
#       <td>155741</td>
#     </tr>
#     <tr>
#       <td>20-30%</td>
#       <td>260880</td>
#     </tr>
#     <tr>
#       <td>30-40%</td>
#       <td>50606</td>
#     </tr>
#     <tr>
#       <td>40-50%</td>
#       <td>155738</td>
#     </tr>
#     <tr>
#       <td>50-60%</td>
#       <td>155742</td>
#     </tr>
#     <tr>
#       <td>60-70%</td>
#       <td>155741</td>
#     </tr>
#     <tr>
#       <td>70-80%</td>
#       <td>155740</td>
#     </tr>
#     <tr>
#       <td>80-90%</td>
#       <td>155741</td>
#     </tr>
#     <tr>
#       <td>90-100%</td>
#       <td>155739</td>
#     </tr>
#   </tbody>
# </table></div>
# 📊 Column: net_profit_margin (n=1557412)
# <div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Summary Statistics</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Statistic</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>count</td>
#       <td>1557412.000000</td>
#     </tr>
#     <tr>
#       <td>mean</td>
#       <td>-9281.732537</td>
#     </tr>
#     <tr>
#       <td>std</td>
#       <td>5297490.200710</td>
#     </tr>
#     <tr>
#       <td>min</td>
#       <td>-3855218855.218855</td>
#     </tr>
#     <tr>
#       <td>0.1%</td>
#       <td>-3782.700650</td>
#     </tr>
#     <tr>
#       <td>1%</td>
#       <td>-62.981909</td>
#     </tr>
#     <tr>
#       <td>5%</td>
#       <td>-2.005582</td>
#     </tr>
#     <tr>
#       <td>10%</td>
#       <td>-0.395340</td>
#     </tr>
#     <tr>
#       <td>20%</td>
#       <td>-0.041467</td>
#     </tr>
#     <tr>
#       <td>30%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>40%</td>
#       <td>0.009246</td>
#     </tr>
#     <tr>
#       <td>50%</td>
#       <td>0.032104</td>
#     </tr>
#     <tr>
#       <td>60%</td>
#       <td>0.057546</td>
#     </tr>
#     <tr>
#       <td>70%</td>
#       <td>0.091491</td>
#     </tr>
#     <tr>
#       <td>80%</td>
#       <td>0.145763</td>
#     </tr>
#     <tr>
#       <td>90%</td>
#       <td>0.269911</td>
#     </tr>
#     <tr>
#       <td>95%</td>
#       <td>0.470851</td>
#     </tr>
#     <tr>
#       <td>99%</td>
#       <td>2.781645</td>
#     </tr>
#     <tr>
#       <td>99.9%</td>
#       <td>311.402371</td>
#     </tr>
#     <tr>
#       <td>max</td>
#       <td>1208477000.000000</td>
#     </tr>
#   </tbody>
# </table></div><div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Counts per Percentile Bucket (10 buckets)</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percentile Bucket</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0-10%</td>
#       <td>155742</td>
#     </tr>
#     <tr>
#       <td>10-20%</td>
#       <td>155741</td>
#     </tr>
#     <tr>
#       <td>20-30%</td>
#       <td>254645</td>
#     </tr>
#     <tr>
#       <td>30-40%</td>
#       <td>56842</td>
#     </tr>
#     <tr>
#       <td>40-50%</td>
#       <td>155739</td>
#     </tr>
#     <tr>
#       <td>50-60%</td>
#       <td>155743</td>
#     </tr>
#     <tr>
#       <td>60-70%</td>
#       <td>155737</td>
#     </tr>
#     <tr>
#       <td>70-80%</td>
#       <td>155740</td>
#     </tr>
#     <tr>
#       <td>80-90%</td>
#       <td>155741</td>
#     </tr>
#     <tr>
#       <td>90-100%</td>
#       <td>155742</td>
#     </tr>
#   </tbody>
# </table></div>
# 📊 Column: bottom_line_profit_margin (n=1557412)
# <div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Summary Statistics</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Statistic</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>count</td>
#       <td>1557412.000000</td>
#     </tr>
#     <tr>
#       <td>mean</td>
#       <td>-7390.243702</td>
#     </tr>
#     <tr>
#       <td>std</td>
#       <td>4571690.829176</td>
#     </tr>
#     <tr>
#       <td>min</td>
#       <td>-3855218855.218855</td>
#     </tr>
#     <tr>
#       <td>0.1%</td>
#       <td>-5558.852052</td>
#     </tr>
#     <tr>
#       <td>1%</td>
#       <td>-65.867284</td>
#     </tr>
#     <tr>
#       <td>5%</td>
#       <td>-2.010701</td>
#     </tr>
#     <tr>
#       <td>10%</td>
#       <td>-0.397354</td>
#     </tr>
#     <tr>
#       <td>20%</td>
#       <td>-0.042078</td>
#     </tr>
#     <tr>
#       <td>30%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>40%</td>
#       <td>0.008834</td>
#     </tr>
#     <tr>
#       <td>50%</td>
#       <td>0.031703</td>
#     </tr>
#     <tr>
#       <td>60%</td>
#       <td>0.057113</td>
#     </tr>
#     <tr>
#       <td>70%</td>
#       <td>0.090975</td>
#     </tr>
#     <tr>
#       <td>80%</td>
#       <td>0.145046</td>
#     </tr>
#     <tr>
#       <td>90%</td>
#       <td>0.268526</td>
#     </tr>
#     <tr>
#       <td>95%</td>
#       <td>0.467651</td>
#     </tr>
#     <tr>
#       <td>99%</td>
#       <td>2.599317</td>
#     </tr>
#     <tr>
#       <td>99.9%</td>
#       <td>319.470379</td>
#     </tr>
#     <tr>
#       <td>max</td>
#       <td>1208477000.000000</td>
#     </tr>
#   </tbody>
# </table></div><div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Counts per Percentile Bucket (10 buckets)</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percentile Bucket</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0-10%</td>
#       <td>155742</td>
#     </tr>
#     <tr>
#       <td>10-20%</td>
#       <td>155742</td>
#     </tr>
#     <tr>
#       <td>20-30%</td>
#       <td>256904</td>
#     </tr>
#     <tr>
#       <td>30-40%</td>
#       <td>54579</td>
#     </tr>
#     <tr>
#       <td>40-50%</td>
#       <td>155745</td>
#     </tr>
#     <tr>
#       <td>50-60%</td>
#       <td>155735</td>
#     </tr>
#     <tr>
#       <td>60-70%</td>
#       <td>155743</td>
#     </tr>
#     <tr>
#       <td>70-80%</td>
#       <td>155741</td>
#     </tr>
#     <tr>
#       <td>80-90%</td>
#       <td>155742</td>
#     </tr>
#     <tr>
#       <td>90-100%</td>
#       <td>155739</td>
#     </tr>
#   </tbody>
# </table></div>
# 📊 Column: current_ratio (n=1557409)
# <div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Summary Statistics</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Statistic</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>count</td>
#       <td>1557409.000000</td>
#     </tr>
#     <tr>
#       <td>mean</td>
#       <td>407.246766</td>
#     </tr>
#     <tr>
#       <td>std</td>
#       <td>211227.126547</td>
#     </tr>
#     <tr>
#       <td>min</td>
#       <td>-19393.524000</td>
#     </tr>
#     <tr>
#       <td>0.1%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>1%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>10%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>20%</td>
#       <td>0.489735</td>
#     </tr>
#     <tr>
#       <td>30%</td>
#       <td>0.955807</td>
#     </tr>
#     <tr>
#       <td>40%</td>
#       <td>1.236016</td>
#     </tr>
#     <tr>
#       <td>50%</td>
#       <td>1.519362</td>
#     </tr>
#     <tr>
#       <td>60%</td>
#       <td>1.884491</td>
#     </tr>
#     <tr>
#       <td>70%</td>
#       <td>2.450104</td>
#     </tr>
#     <tr>
#       <td>80%</td>
#       <td>3.539139</td>
#     </tr>
#     <tr>
#       <td>90%</td>
#       <td>6.880053</td>
#     </tr>
#     <tr>
#       <td>95%</td>
#       <td>14.357612</td>
#     </tr>
#     <tr>
#       <td>99%</td>
#       <td>103.176842</td>
#     </tr>
#     <tr>
#       <td>99.9%</td>
#       <td>5116.380477</td>
#     </tr>
#     <tr>
#       <td>max</td>
#       <td>185015535.153558</td>
#     </tr>
#   </tbody>
# </table></div><div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Counts per Percentile Bucket (10 buckets)</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percentile Bucket</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0-10%</td>
#       <td>199738</td>
#     </tr>
#     <tr>
#       <td>10-20%</td>
#       <td>111744</td>
#     </tr>
#     <tr>
#       <td>20-30%</td>
#       <td>155741</td>
#     </tr>
#     <tr>
#       <td>30-40%</td>
#       <td>155741</td>
#     </tr>
#     <tr>
#       <td>40-50%</td>
#       <td>155741</td>
#     </tr>
#     <tr>
#       <td>50-60%</td>
#       <td>155740</td>
#     </tr>
#     <tr>
#       <td>60-70%</td>
#       <td>155741</td>
#     </tr>
#     <tr>
#       <td>70-80%</td>
#       <td>155741</td>
#     </tr>
#     <tr>
#       <td>80-90%</td>
#       <td>155741</td>
#     </tr>
#     <tr>
#       <td>90-100%</td>
#       <td>155741</td>
#     </tr>
#   </tbody>
# </table></div>
# 📊 Column: quick_ratio (n=1557396)
# <div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Summary Statistics</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Statistic</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>count</td>
#       <td>1557396.000000</td>
#     </tr>
#     <tr>
#       <td>mean</td>
#       <td>491.074381</td>
#     </tr>
#     <tr>
#       <td>std</td>
#       <td>222277.771716</td>
#     </tr>
#     <tr>
#       <td>min</td>
#       <td>-191420.868588</td>
#     </tr>
#     <tr>
#       <td>0.1%</td>
#       <td>-1.596835</td>
#     </tr>
#     <tr>
#       <td>1%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>10%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>20%</td>
#       <td>0.321628</td>
#     </tr>
#     <tr>
#       <td>30%</td>
#       <td>0.640300</td>
#     </tr>
#     <tr>
#       <td>40%</td>
#       <td>0.887279</td>
#     </tr>
#     <tr>
#       <td>50%</td>
#       <td>1.131889</td>
#     </tr>
#     <tr>
#       <td>60%</td>
#       <td>1.443594</td>
#     </tr>
#     <tr>
#       <td>70%</td>
#       <td>1.935645</td>
#     </tr>
#     <tr>
#       <td>80%</td>
#       <td>2.945165</td>
#     </tr>
#     <tr>
#       <td>90%</td>
#       <td>6.223863</td>
#     </tr>
#     <tr>
#       <td>95%</td>
#       <td>13.831397</td>
#     </tr>
#     <tr>
#       <td>99%</td>
#       <td>109.068504</td>
#     </tr>
#     <tr>
#       <td>99.9%</td>
#       <td>5204.087297</td>
#     </tr>
#     <tr>
#       <td>max</td>
#       <td>185015535.153558</td>
#     </tr>
#   </tbody>
# </table></div><div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Counts per Percentile Bucket (10 buckets)</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percentile Bucket</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0-10%</td>
#       <td>202743</td>
#     </tr>
#     <tr>
#       <td>10-20%</td>
#       <td>108737</td>
#     </tr>
#     <tr>
#       <td>20-30%</td>
#       <td>155739</td>
#     </tr>
#     <tr>
#       <td>30-40%</td>
#       <td>155740</td>
#     </tr>
#     <tr>
#       <td>40-50%</td>
#       <td>155740</td>
#     </tr>
#     <tr>
#       <td>50-60%</td>
#       <td>155739</td>
#     </tr>
#     <tr>
#       <td>60-70%</td>
#       <td>155739</td>
#     </tr>
#     <tr>
#       <td>70-80%</td>
#       <td>155741</td>
#     </tr>
#     <tr>
#       <td>80-90%</td>
#       <td>155738</td>
#     </tr>
#     <tr>
#       <td>90-100%</td>
#       <td>155740</td>
#     </tr>
#   </tbody>
# </table></div>
# 📊 Column: solvency_ratio (n=1536694)
# <div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Summary Statistics</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Statistic</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>count</td>
#       <td>1536694.000000</td>
#     </tr>
#     <tr>
#       <td>mean</td>
#       <td>-2421.908928</td>
#     </tr>
#     <tr>
#       <td>std</td>
#       <td>2444150.828611</td>
#     </tr>
#     <tr>
#       <td>min</td>
#       <td>-2611722988.239018</td>
#     </tr>
#     <tr>
#       <td>0.1%</td>
#       <td>-82.793980</td>
#     </tr>
#     <tr>
#       <td>1%</td>
#       <td>-3.989010</td>
#     </tr>
#     <tr>
#       <td>5%</td>
#       <td>-0.668445</td>
#     </tr>
#     <tr>
#       <td>10%</td>
#       <td>-0.167825</td>
#     </tr>
#     <tr>
#       <td>20%</td>
#       <td>-0.014294</td>
#     </tr>
#     <tr>
#       <td>30%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>40%</td>
#       <td>0.003443</td>
#     </tr>
#     <tr>
#       <td>50%</td>
#       <td>0.016001</td>
#     </tr>
#     <tr>
#       <td>60%</td>
#       <td>0.029584</td>
#     </tr>
#     <tr>
#       <td>70%</td>
#       <td>0.047165</td>
#     </tr>
#     <tr>
#       <td>80%</td>
#       <td>0.076623</td>
#     </tr>
#     <tr>
#       <td>90%</td>
#       <td>0.149786</td>
#     </tr>
#     <tr>
#       <td>95%</td>
#       <td>0.264507</td>
#     </tr>
#     <tr>
#       <td>99%</td>
#       <td>1.164105</td>
#     </tr>
#     <tr>
#       <td>99.9%</td>
#       <td>45.355294</td>
#     </tr>
#     <tr>
#       <td>max</td>
#       <td>348759556.000000</td>
#     </tr>
#   </tbody>
# </table></div><div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Counts per Percentile Bucket (10 buckets)</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percentile Bucket</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0-10%</td>
#       <td>153670</td>
#     </tr>
#     <tr>
#       <td>10-20%</td>
#       <td>153669</td>
#     </tr>
#     <tr>
#       <td>20-30%</td>
#       <td>251449</td>
#     </tr>
#     <tr>
#       <td>30-40%</td>
#       <td>55905</td>
#     </tr>
#     <tr>
#       <td>40-50%</td>
#       <td>153660</td>
#     </tr>
#     <tr>
#       <td>50-60%</td>
#       <td>153665</td>
#     </tr>
#     <tr>
#       <td>60-70%</td>
#       <td>153673</td>
#     </tr>
#     <tr>
#       <td>70-80%</td>
#       <td>153665</td>
#     </tr>
#     <tr>
#       <td>80-90%</td>
#       <td>153668</td>
#     </tr>
#     <tr>
#       <td>90-100%</td>
#       <td>153670</td>
#     </tr>
#   </tbody>
# </table></div>
# 📊 Column: cash_ratio (n=1557410)
# <div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Summary Statistics</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Statistic</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>count</td>
#       <td>1557410.000000</td>
#     </tr>
#     <tr>
#       <td>mean</td>
#       <td>-3738.275906</td>
#     </tr>
#     <tr>
#       <td>std</td>
#       <td>4716212.050464</td>
#     </tr>
#     <tr>
#       <td>min</td>
#       <td>-5885647325.693740</td>
#     </tr>
#     <tr>
#       <td>0.1%</td>
#       <td>-0.156728</td>
#     </tr>
#     <tr>
#       <td>1%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>10%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>20%</td>
#       <td>0.029929</td>
#     </tr>
#     <tr>
#       <td>30%</td>
#       <td>0.104227</td>
#     </tr>
#     <tr>
#       <td>40%</td>
#       <td>0.197740</td>
#     </tr>
#     <tr>
#       <td>50%</td>
#       <td>0.316137</td>
#     </tr>
#     <tr>
#       <td>60%</td>
#       <td>0.488020</td>
#     </tr>
#     <tr>
#       <td>70%</td>
#       <td>0.772556</td>
#     </tr>
#     <tr>
#       <td>80%</td>
#       <td>1.351700</td>
#     </tr>
#     <tr>
#       <td>90%</td>
#       <td>3.306803</td>
#     </tr>
#     <tr>
#       <td>95%</td>
#       <td>7.749016</td>
#     </tr>
#     <tr>
#       <td>99%</td>
#       <td>52.659925</td>
#     </tr>
#     <tr>
#       <td>99.9%</td>
#       <td>1389.679475</td>
#     </tr>
#     <tr>
#       <td>max</td>
#       <td>5533848.600000</td>
#     </tr>
#   </tbody>
# </table></div><div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Counts per Percentile Bucket (10 buckets)</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percentile Bucket</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0-10%</td>
#       <td>207256</td>
#     </tr>
#     <tr>
#       <td>10-20%</td>
#       <td>104230</td>
#     </tr>
#     <tr>
#       <td>20-30%</td>
#       <td>155739</td>
#     </tr>
#     <tr>
#       <td>30-40%</td>
#       <td>155740</td>
#     </tr>
#     <tr>
#       <td>40-50%</td>
#       <td>155740</td>
#     </tr>
#     <tr>
#       <td>50-60%</td>
#       <td>155741</td>
#     </tr>
#     <tr>
#       <td>60-70%</td>
#       <td>155741</td>
#     </tr>
#     <tr>
#       <td>70-80%</td>
#       <td>155741</td>
#     </tr>
#     <tr>
#       <td>80-90%</td>
#       <td>155741</td>
#     </tr>
#     <tr>
#       <td>90-100%</td>
#       <td>155741</td>
#     </tr>
#   </tbody>
# </table></div>
# 📊 Column: receivables_turnover (n=1545739)
# <div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Summary Statistics</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Statistic</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>count</td>
#       <td>1545739.000000</td>
#     </tr>
#     <tr>
#       <td>mean</td>
#       <td>428000.986269</td>
#     </tr>
#     <tr>
#       <td>std</td>
#       <td>44414139.325541</td>
#     </tr>
#     <tr>
#       <td>min</td>
#       <td>-9241483286.000000</td>
#     </tr>
#     <tr>
#       <td>0.1%</td>
#       <td>-78.537707</td>
#     </tr>
#     <tr>
#       <td>1%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>10%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>20%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>30%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>40%</td>
#       <td>0.459861</td>
#     </tr>
#     <tr>
#       <td>50%</td>
#       <td>0.881321</td>
#     </tr>
#     <tr>
#       <td>60%</td>
#       <td>1.228817</td>
#     </tr>
#     <tr>
#       <td>70%</td>
#       <td>1.644348</td>
#     </tr>
#     <tr>
#       <td>80%</td>
#       <td>2.324022</td>
#     </tr>
#     <tr>
#       <td>90%</td>
#       <td>4.339494</td>
#     </tr>
#     <tr>
#       <td>95%</td>
#       <td>9.355955</td>
#     </tr>
#     <tr>
#       <td>99%</td>
#       <td>67.845298</td>
#     </tr>
#     <tr>
#       <td>99.9%</td>
#       <td>152855.677862</td>
#     </tr>
#     <tr>
#       <td>max</td>
#       <td>9444884216.544235</td>
#     </tr>
#   </tbody>
# </table></div><div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Counts per Percentile Bucket (10 buckets)</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percentile Bucket</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0-10%</td>
#       <td>516992</td>
#     </tr>
#     <tr>
#       <td>10-20%</td>
#       <td>101304</td>
#     </tr>
#     <tr>
#       <td>20-30%</td>
#       <td>154574</td>
#     </tr>
#     <tr>
#       <td>30-40%</td>
#       <td>154573</td>
#     </tr>
#     <tr>
#       <td>40-50%</td>
#       <td>154574</td>
#     </tr>
#     <tr>
#       <td>50-60%</td>
#       <td>154574</td>
#     </tr>
#     <tr>
#       <td>60-70%</td>
#       <td>154574</td>
#     </tr>
#     <tr>
#       <td>70-80%</td>
#       <td>154574</td>
#     </tr>
#   </tbody>
# </table></div>
# 📊 Column: payables_turnover (n=1539388)
# <div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Summary Statistics</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Statistic</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>count</td>
#       <td>1539388.000000</td>
#     </tr>
#     <tr>
#       <td>mean</td>
#       <td>7920.778435</td>
#     </tr>
#     <tr>
#       <td>std</td>
#       <td>7755296.301785</td>
#     </tr>
#     <tr>
#       <td>min</td>
#       <td>-2818284.790878</td>
#     </tr>
#     <tr>
#       <td>0.1%</td>
#       <td>-2.986233</td>
#     </tr>
#     <tr>
#       <td>1%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>10%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>20%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>30%</td>
#       <td>0.052212</td>
#     </tr>
#     <tr>
#       <td>40%</td>
#       <td>0.572924</td>
#     </tr>
#     <tr>
#       <td>50%</td>
#       <td>1.007994</td>
#     </tr>
#     <tr>
#       <td>60%</td>
#       <td>1.448801</td>
#     </tr>
#     <tr>
#       <td>70%</td>
#       <td>2.006064</td>
#     </tr>
#     <tr>
#       <td>80%</td>
#       <td>2.873754</td>
#     </tr>
#     <tr>
#       <td>90%</td>
#       <td>4.902418</td>
#     </tr>
#     <tr>
#       <td>95%</td>
#       <td>8.505611</td>
#     </tr>
#     <tr>
#       <td>99%</td>
#       <td>39.593179</td>
#     </tr>
#     <tr>
#       <td>99.9%</td>
#       <td>1158.853389</td>
#     </tr>
#     <tr>
#       <td>max</td>
#       <td>9435376750.333334</td>
#     </tr>
#   </tbody>
# </table></div><div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Counts per Percentile Bucket (10 buckets)</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percentile Bucket</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0-10%</td>
#       <td>426880</td>
#     </tr>
#     <tr>
#       <td>10-20%</td>
#       <td>34937</td>
#     </tr>
#     <tr>
#       <td>20-30%</td>
#       <td>153938</td>
#     </tr>
#     <tr>
#       <td>30-40%</td>
#       <td>153939</td>
#     </tr>
#     <tr>
#       <td>40-50%</td>
#       <td>153939</td>
#     </tr>
#     <tr>
#       <td>50-60%</td>
#       <td>153939</td>
#     </tr>
#     <tr>
#       <td>60-70%</td>
#       <td>153939</td>
#     </tr>
#     <tr>
#       <td>70-80%</td>
#       <td>153938</td>
#     </tr>
#     <tr>
#       <td>80-90%</td>
#       <td>153939</td>
#     </tr>
#   </tbody>
# </table></div>
# 📊 Column: inventory_turnover (n=1543884)
# <div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Summary Statistics</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Statistic</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>count</td>
#       <td>1543884.000000</td>
#     </tr>
#     <tr>
#       <td>mean</td>
#       <td>22629.497711</td>
#     </tr>
#     <tr>
#       <td>std</td>
#       <td>16207145.804561</td>
#     </tr>
#     <tr>
#       <td>min</td>
#       <td>-9150685977.229599</td>
#     </tr>
#     <tr>
#       <td>0.1%</td>
#       <td>-245.389194</td>
#     </tr>
#     <tr>
#       <td>1%</td>
#       <td>-0.902299</td>
#     </tr>
#     <tr>
#       <td>5%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>10%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>20%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>30%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>40%</td>
#       <td>0.115926</td>
#     </tr>
#     <tr>
#       <td>50%</td>
#       <td>0.551923</td>
#     </tr>
#     <tr>
#       <td>60%</td>
#       <td>0.923392</td>
#     </tr>
#     <tr>
#       <td>70%</td>
#       <td>1.425055</td>
#     </tr>
#     <tr>
#       <td>80%</td>
#       <td>2.438080</td>
#     </tr>
#     <tr>
#       <td>90%</td>
#       <td>6.736886</td>
#     </tr>
#     <tr>
#       <td>95%</td>
#       <td>19.057734</td>
#     </tr>
#     <tr>
#       <td>99%</td>
#       <td>223.893301</td>
#     </tr>
#     <tr>
#       <td>99.9%</td>
#       <td>14311.284828</td>
#     </tr>
#     <tr>
#       <td>max</td>
#       <td>8417518000.000000</td>
#     </tr>
#   </tbody>
# </table></div><div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Counts per Percentile Bucket (10 buckets)</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percentile Bucket</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0-10%</td>
#       <td>575648</td>
#     </tr>
#     <tr>
#       <td>10-20%</td>
#       <td>41907</td>
#     </tr>
#     <tr>
#       <td>20-30%</td>
#       <td>154387</td>
#     </tr>
#     <tr>
#       <td>30-40%</td>
#       <td>154388</td>
#     </tr>
#     <tr>
#       <td>40-50%</td>
#       <td>154389</td>
#     </tr>
#     <tr>
#       <td>50-60%</td>
#       <td>154388</td>
#     </tr>
#     <tr>
#       <td>60-70%</td>
#       <td>154388</td>
#     </tr>
#     <tr>
#       <td>70-80%</td>
#       <td>154389</td>
#     </tr>
#   </tbody>
# </table></div>
# 📊 Column: fixed_asset_turnover (n=1539764)
# <div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Summary Statistics</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Statistic</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>count</td>
#       <td>1539764.000000</td>
#     </tr>
#     <tr>
#       <td>mean</td>
#       <td>411.336613</td>
#     </tr>
#     <tr>
#       <td>std</td>
#       <td>449570.348079</td>
#     </tr>
#     <tr>
#       <td>min</td>
#       <td>-4059429.319372</td>
#     </tr>
#     <tr>
#       <td>0.1%</td>
#       <td>-11.268483</td>
#     </tr>
#     <tr>
#       <td>1%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>10%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>20%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>30%</td>
#       <td>0.152822</td>
#     </tr>
#     <tr>
#       <td>40%</td>
#       <td>0.377649</td>
#     </tr>
#     <tr>
#       <td>50%</td>
#       <td>0.621229</td>
#     </tr>
#     <tr>
#       <td>60%</td>
#       <td>0.942493</td>
#     </tr>
#     <tr>
#       <td>70%</td>
#       <td>1.496465</td>
#     </tr>
#     <tr>
#       <td>80%</td>
#       <td>2.741183</td>
#     </tr>
#     <tr>
#       <td>90%</td>
#       <td>7.363402</td>
#     </tr>
#     <tr>
#       <td>95%</td>
#       <td>17.744708</td>
#     </tr>
#     <tr>
#       <td>99%</td>
#       <td>115.107403</td>
#     </tr>
#     <tr>
#       <td>99.9%</td>
#       <td>2154.547583</td>
#     </tr>
#     <tr>
#       <td>max</td>
#       <td>557572812.167722</td>
#     </tr>
#   </tbody>
# </table></div><div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Counts per Percentile Bucket (10 buckets)</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percentile Bucket</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0-10%</td>
#       <td>334642</td>
#     </tr>
#     <tr>
#       <td>10-20%</td>
#       <td>127287</td>
#     </tr>
#     <tr>
#       <td>20-30%</td>
#       <td>153978</td>
#     </tr>
#     <tr>
#       <td>30-40%</td>
#       <td>153975</td>
#     </tr>
#     <tr>
#       <td>40-50%</td>
#       <td>153977</td>
#     </tr>
#     <tr>
#       <td>50-60%</td>
#       <td>153976</td>
#     </tr>
#     <tr>
#       <td>60-70%</td>
#       <td>153976</td>
#     </tr>
#     <tr>
#       <td>70-80%</td>
#       <td>153976</td>
#     </tr>
#     <tr>
#       <td>80-90%</td>
#       <td>153977</td>
#     </tr>
#   </tbody>
# </table></div>
# 📊 Column: asset_turnover (n=1536580)
# <div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Summary Statistics</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Statistic</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>count</td>
#       <td>1536580.000000</td>
#     </tr>
#     <tr>
#       <td>mean</td>
#       <td>1938.468667</td>
#     </tr>
#     <tr>
#       <td>std</td>
#       <td>2323557.986223</td>
#     </tr>
#     <tr>
#       <td>min</td>
#       <td>-372313.756249</td>
#     </tr>
#     <tr>
#       <td>0.1%</td>
#       <td>-0.160125</td>
#     </tr>
#     <tr>
#       <td>1%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>10%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>20%</td>
#       <td>0.000794</td>
#     </tr>
#     <tr>
#       <td>30%</td>
#       <td>0.026157</td>
#     </tr>
#     <tr>
#       <td>40%</td>
#       <td>0.070671</td>
#     </tr>
#     <tr>
#       <td>50%</td>
#       <td>0.117387</td>
#     </tr>
#     <tr>
#       <td>60%</td>
#       <td>0.164175</td>
#     </tr>
#     <tr>
#       <td>70%</td>
#       <td>0.215223</td>
#     </tr>
#     <tr>
#       <td>80%</td>
#       <td>0.285279</td>
#     </tr>
#     <tr>
#       <td>90%</td>
#       <td>0.416039</td>
#     </tr>
#     <tr>
#       <td>95%</td>
#       <td>0.573491</td>
#     </tr>
#     <tr>
#       <td>99%</td>
#       <td>1.124363</td>
#     </tr>
#     <tr>
#       <td>99.9%</td>
#       <td>5.128410</td>
#     </tr>
#     <tr>
#       <td>max</td>
#       <td>2880000000.000000</td>
#     </tr>
#   </tbody>
# </table></div><div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Counts per Percentile Bucket (10 buckets)</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percentile Bucket</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0-10%</td>
#       <td>294984</td>
#     </tr>
#     <tr>
#       <td>10-20%</td>
#       <td>12337</td>
#     </tr>
#     <tr>
#       <td>20-30%</td>
#       <td>153654</td>
#     </tr>
#     <tr>
#       <td>30-40%</td>
#       <td>153657</td>
#     </tr>
#     <tr>
#       <td>40-50%</td>
#       <td>153664</td>
#     </tr>
#     <tr>
#       <td>50-60%</td>
#       <td>153653</td>
#     </tr>
#     <tr>
#       <td>60-70%</td>
#       <td>153657</td>
#     </tr>
#     <tr>
#       <td>70-80%</td>
#       <td>153659</td>
#     </tr>
#     <tr>
#       <td>80-90%</td>
#       <td>153657</td>
#     </tr>
#     <tr>
#       <td>90-100%</td>
#       <td>153658</td>
#     </tr>
#   </tbody>
# </table></div>
# 📊 Column: working_capital_turnover_ratio (n=1552265)
# <div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Summary Statistics</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Statistic</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>count</td>
#       <td>1552265.000000</td>
#     </tr>
#     <tr>
#       <td>mean</td>
#       <td>-6725.560013</td>
#     </tr>
#     <tr>
#       <td>std</td>
#       <td>6068565.527972</td>
#     </tr>
#     <tr>
#       <td>min</td>
#       <td>-5344170720.000000</td>
#     </tr>
#     <tr>
#       <td>0.1%</td>
#       <td>-258.832961</td>
#     </tr>
#     <tr>
#       <td>1%</td>
#       <td>-22.050811</td>
#     </tr>
#     <tr>
#       <td>5%</td>
#       <td>-3.042164</td>
#     </tr>
#     <tr>
#       <td>10%</td>
#       <td>-0.665053</td>
#     </tr>
#     <tr>
#       <td>20%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>30%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>40%</td>
#       <td>0.058344</td>
#     </tr>
#     <tr>
#       <td>50%</td>
#       <td>0.280634</td>
#     </tr>
#     <tr>
#       <td>60%</td>
#       <td>0.529184</td>
#     </tr>
#     <tr>
#       <td>70%</td>
#       <td>0.872328</td>
#     </tr>
#     <tr>
#       <td>80%</td>
#       <td>1.462639</td>
#     </tr>
#     <tr>
#       <td>90%</td>
#       <td>3.001283</td>
#     </tr>
#     <tr>
#       <td>95%</td>
#       <td>5.782282</td>
#     </tr>
#     <tr>
#       <td>99%</td>
#       <td>26.498537</td>
#     </tr>
#     <tr>
#       <td>99.9%</td>
#       <td>313.898020</td>
#     </tr>
#     <tr>
#       <td>max</td>
#       <td>212276056.338028</td>
#     </tr>
#   </tbody>
# </table></div><div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Counts per Percentile Bucket (10 buckets)</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percentile Bucket</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0-10%</td>
#       <td>155227</td>
#     </tr>
#     <tr>
#       <td>10-20%</td>
#       <td>395372</td>
#     </tr>
#     <tr>
#       <td>20-30%</td>
#       <td>70307</td>
#     </tr>
#     <tr>
#       <td>30-40%</td>
#       <td>155227</td>
#     </tr>
#     <tr>
#       <td>40-50%</td>
#       <td>155226</td>
#     </tr>
#     <tr>
#       <td>50-60%</td>
#       <td>155227</td>
#     </tr>
#     <tr>
#       <td>60-70%</td>
#       <td>155226</td>
#     </tr>
#     <tr>
#       <td>70-80%</td>
#       <td>155226</td>
#     </tr>
#     <tr>
#       <td>80-90%</td>
#       <td>155227</td>
#     </tr>
#   </tbody>
# </table></div>
# 📊 Column: price_to_earnings_ratio (n=1552894)
# <div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Summary Statistics</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Statistic</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>count</td>
#       <td>1552894.000000</td>
#     </tr>
#     <tr>
#       <td>mean</td>
#       <td>-26376.799584</td>
#     </tr>
#     <tr>
#       <td>std</td>
#       <td>15384662.483807</td>
#     </tr>
#     <tr>
#       <td>min</td>
#       <td>-6464285694.486983</td>
#     </tr>
#     <tr>
#       <td>0.1%</td>
#       <td>-54974.615838</td>
#     </tr>
#     <tr>
#       <td>1%</td>
#       <td>-930.077367</td>
#     </tr>
#     <tr>
#       <td>5%</td>
#       <td>-73.301127</td>
#     </tr>
#     <tr>
#       <td>10%</td>
#       <td>-24.445054</td>
#     </tr>
#     <tr>
#       <td>20%</td>
#       <td>-5.715671</td>
#     </tr>
#     <tr>
#       <td>30%</td>
#       <td>-0.697282</td>
#     </tr>
#     <tr>
#       <td>40%</td>
#       <td>2.803582</td>
#     </tr>
#     <tr>
#       <td>50%</td>
#       <td>7.223637</td>
#     </tr>
#     <tr>
#       <td>60%</td>
#       <td>11.564614</td>
#     </tr>
#     <tr>
#       <td>70%</td>
#       <td>17.178725</td>
#     </tr>
#     <tr>
#       <td>80%</td>
#       <td>26.895656</td>
#     </tr>
#     <tr>
#       <td>90%</td>
#       <td>54.199305</td>
#     </tr>
#     <tr>
# ...
#       <td>29071</td>
#     </tr>
#     <tr>
#       <td>40-50%</td>
#       <td>150502</td>
#     </tr>
#     <tr>
#       <td>50-60%</td>
#       <td>150504</td>
#     </tr>
#     <tr>
#       <td>60-70%</td>
#       <td>150506</td>
#     </tr>
#     <tr>
#       <td>70-80%</td>
#       <td>150504</td>
#     </tr>
#     <tr>
#       <td>80-90%</td>
#       <td>150506</td>
#     </tr>
#   </tbody>
# </table></div>
# 📊 Column: capex_per_share (n=1505111)
# <div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Summary Statistics</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Statistic</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>count</td>
#       <td>1505111.000000</td>
#     </tr>
#     <tr>
#       <td>mean</td>
#       <td>8220.232517</td>
#     </tr>
#     <tr>
#       <td>std</td>
#       <td>2412844.897794</td>
#     </tr>
#     <tr>
#       <td>min</td>
#       <td>-0.027105</td>
#     </tr>
#     <tr>
#       <td>0.1%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>1%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>10%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>20%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>30%</td>
#       <td>0.000143</td>
#     </tr>
#     <tr>
#       <td>40%</td>
#       <td>0.004716</td>
#     </tr>
#     <tr>
#       <td>50%</td>
#       <td>0.020088</td>
#     </tr>
#     <tr>
#       <td>60%</td>
#       <td>0.056138</td>
#     </tr>
#     <tr>
#       <td>70%</td>
#       <td>0.136662</td>
#     </tr>
#     <tr>
#       <td>80%</td>
#       <td>0.356240</td>
#     </tr>
#     <tr>
#       <td>90%</td>
#       <td>1.602160</td>
#     </tr>
#     <tr>
#       <td>95%</td>
#       <td>11.660626</td>
#     </tr>
#     <tr>
#       <td>99%</td>
#       <td>548.656210</td>
#     </tr>
#     <tr>
#       <td>99.9%</td>
#       <td>12461.695263</td>
#     </tr>
#     <tr>
#       <td>max</td>
#       <td>1722361654.673233</td>
#     </tr>
#   </tbody>
# </table></div><div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Counts per Percentile Bucket (10 buckets)</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percentile Bucket</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0-10%</td>
#       <td>415969</td>
#     </tr>
#     <tr>
#       <td>10-20%</td>
#       <td>35689</td>
#     </tr>
#     <tr>
#       <td>20-30%</td>
#       <td>150389</td>
#     </tr>
#     <tr>
#       <td>30-40%</td>
#       <td>150510</td>
#     </tr>
#     <tr>
#       <td>40-50%</td>
#       <td>150511</td>
#     </tr>
#     <tr>
#       <td>50-60%</td>
#       <td>150510</td>
#     </tr>
#     <tr>
#       <td>60-70%</td>
#       <td>150511</td>
#     </tr>
#     <tr>
#       <td>70-80%</td>
#       <td>150511</td>
#     </tr>
#     <tr>
#       <td>80-90%</td>
#       <td>150511</td>
#     </tr>
#   </tbody>
# </table></div>
# 📊 Column: free_cash_flow_per_share (n=1505139)
# <div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Summary Statistics</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Statistic</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>count</td>
#       <td>1505139.000000</td>
#     </tr>
#     <tr>
#       <td>mean</td>
#       <td>-31305.760743</td>
#     </tr>
#     <tr>
#       <td>std</td>
#       <td>14677727.368329</td>
#     </tr>
#     <tr>
#       <td>min</td>
#       <td>-9711885152.998062</td>
#     </tr>
#     <tr>
#       <td>0.1%</td>
#       <td>-15220.616783</td>
#     </tr>
#     <tr>
#       <td>1%</td>
#       <td>-399.624834</td>
#     </tr>
#     <tr>
#       <td>5%</td>
#       <td>-4.510655</td>
#     </tr>
#     <tr>
#       <td>10%</td>
#       <td>-0.934656</td>
#     </tr>
#     <tr>
#       <td>20%</td>
#       <td>-0.169993</td>
#     </tr>
#     <tr>
#       <td>30%</td>
#       <td>-0.027006</td>
#     </tr>
#     <tr>
#       <td>40%</td>
#       <td>-0.000170</td>
#     </tr>
#     <tr>
#       <td>50%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>60%</td>
#       <td>0.010668</td>
#     </tr>
#     <tr>
#       <td>70%</td>
#       <td>0.125175</td>
#     </tr>
#     <tr>
#       <td>80%</td>
#       <td>0.480123</td>
#     </tr>
#     <tr>
#       <td>90%</td>
#       <td>2.002433</td>
#     </tr>
#     <tr>
#       <td>95%</td>
#       <td>9.407311</td>
#     </tr>
#     <tr>
#       <td>99%</td>
#       <td>488.007022</td>
#     </tr>
#     <tr>
#       <td>99.9%</td>
#       <td>9978.245231</td>
#     </tr>
#     <tr>
#       <td>max</td>
#       <td>1059000000.000000</td>
#     </tr>
#   </tbody>
# </table></div><div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Counts per Percentile Bucket (10 buckets)</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percentile Bucket</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0-10%</td>
#       <td>150514</td>
#     </tr>
#     <tr>
#       <td>10-20%</td>
#       <td>150514</td>
#     </tr>
#     <tr>
#       <td>20-30%</td>
#       <td>150515</td>
#     </tr>
#     <tr>
#       <td>30-40%</td>
#       <td>150514</td>
#     </tr>
#     <tr>
#       <td>40-50%</td>
#       <td>256818</td>
#     </tr>
#     <tr>
#       <td>50-60%</td>
#       <td>44209</td>
#     </tr>
#     <tr>
#       <td>60-70%</td>
#       <td>150514</td>
#     </tr>
#     <tr>
#       <td>70-80%</td>
#       <td>150513</td>
#     </tr>
#     <tr>
#       <td>80-90%</td>
#       <td>150514</td>
#     </tr>
#     <tr>
#       <td>90-100%</td>
#       <td>150514</td>
#     </tr>
#   </tbody>
# </table></div>
# 📊 Column: net_income_per_ebt (n=1556843)
# <div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Summary Statistics</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Statistic</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>count</td>
#       <td>1556843.000000</td>
#     </tr>
#     <tr>
#       <td>mean</td>
#       <td>791979.517648</td>
#     </tr>
#     <tr>
#       <td>std</td>
#       <td>102314544.324972</td>
#     </tr>
#     <tr>
#       <td>min</td>
#       <td>-9882282380.952381</td>
#     </tr>
#     <tr>
#       <td>0.1%</td>
#       <td>-45.786556</td>
#     </tr>
#     <tr>
#       <td>1%</td>
#       <td>-1.688214</td>
#     </tr>
#     <tr>
#       <td>5%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>10%</td>
#       <td>0.458777</td>
#     </tr>
#     <tr>
#       <td>20%</td>
#       <td>0.649540</td>
#     </tr>
#     <tr>
#       <td>30%</td>
#       <td>0.715553</td>
#     </tr>
#     <tr>
#       <td>40%</td>
#       <td>0.766292</td>
#     </tr>
#     <tr>
#       <td>50%</td>
#       <td>0.819222</td>
#     </tr>
#     <tr>
#       <td>60%</td>
#       <td>0.893883</td>
#     </tr>
#     <tr>
#       <td>70%</td>
#       <td>0.994152</td>
#     </tr>
#     <tr>
#       <td>80%</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>90%</td>
#       <td>1.037796</td>
#     </tr>
#     <tr>
#       <td>95%</td>
#       <td>1.277585</td>
#     </tr>
#     <tr>
#       <td>99%</td>
#       <td>3.874922</td>
#     </tr>
#     <tr>
#       <td>99.9%</td>
#       <td>1000.000000</td>
#     </tr>
#     <tr>
#       <td>max</td>
#       <td>9932336570.032574</td>
#     </tr>
#   </tbody>
# </table></div><div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Counts per Percentile Bucket (10 buckets)</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percentile Bucket</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0-10%</td>
#       <td>155685</td>
#     </tr>
#     <tr>
#       <td>10-20%</td>
#       <td>155685</td>
#     </tr>
#     <tr>
#       <td>20-30%</td>
#       <td>155686</td>
#     </tr>
#     <tr>
#       <td>30-40%</td>
#       <td>155685</td>
#     </tr>
#     <tr>
#       <td>40-50%</td>
#       <td>155683</td>
#     </tr>
#     <tr>
#       <td>50-60%</td>
#       <td>155682</td>
#     </tr>
#     <tr>
#       <td>60-70%</td>
#       <td>155684</td>
#     </tr>
#     <tr>
#       <td>70-80%</td>
#       <td>238045</td>
#     </tr>
#     <tr>
#       <td>80-90%</td>
#       <td>73324</td>
#     </tr>
#     <tr>
#       <td>90-100%</td>
#       <td>155684</td>
#     </tr>
#   </tbody>
# </table></div>
# 📊 Column: ebt_per_ebit (n=1557404)
# <div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Summary Statistics</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Statistic</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>count</td>
#       <td>1557404.000000</td>
#     </tr>
#     <tr>
#       <td>mean</td>
#       <td>2518.682675</td>
#     </tr>
#     <tr>
#       <td>std</td>
#       <td>5791877.164853</td>
#     </tr>
#     <tr>
#       <td>min</td>
#       <td>-3448599150.000000</td>
#     </tr>
#     <tr>
#       <td>0.1%</td>
#       <td>-128.162378</td>
#     </tr>
#     <tr>
#       <td>1%</td>
#       <td>-9.522640</td>
#     </tr>
#     <tr>
#       <td>5%</td>
#       <td>-0.679332</td>
#     </tr>
#     <tr>
#       <td>10%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>20%</td>
#       <td>0.589197</td>
#     </tr>
#     <tr>
#       <td>30%</td>
#       <td>0.828136</td>
#     </tr>
#     <tr>
#       <td>40%</td>
#       <td>0.938872</td>
#     </tr>
#     <tr>
#       <td>50%</td>
#       <td>0.991782</td>
#     </tr>
#     <tr>
#       <td>60%</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>70%</td>
#       <td>1.025801</td>
#     </tr>
#     <tr>
#       <td>80%</td>
#       <td>1.123689</td>
#     </tr>
#     <tr>
#       <td>90%</td>
#       <td>1.513668</td>
#     </tr>
#     <tr>
#       <td>95%</td>
#       <td>2.470588</td>
#     </tr>
#     <tr>
#       <td>99%</td>
#       <td>12.102741</td>
#     </tr>
#     <tr>
#       <td>99.9%</td>
#       <td>283.164826</td>
#     </tr>
#     <tr>
#       <td>max</td>
#       <td>6174831700.000000</td>
#     </tr>
#   </tbody>
# </table></div><div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Counts per Percentile Bucket (10 buckets)</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percentile Bucket</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0-10%</td>
#       <td>169893</td>
#     </tr>
#     <tr>
#       <td>10-20%</td>
#       <td>141588</td>
#     </tr>
#     <tr>
#       <td>20-30%</td>
#       <td>155740</td>
#     </tr>
#     <tr>
#       <td>30-40%</td>
#       <td>155743</td>
#     </tr>
#     <tr>
#       <td>40-50%</td>
#       <td>155742</td>
#     </tr>
#     <tr>
#       <td>50-60%</td>
#       <td>172684</td>
#     </tr>
#     <tr>
#       <td>60-70%</td>
#       <td>138795</td>
#     </tr>
#     <tr>
#       <td>70-80%</td>
#       <td>155738</td>
#     </tr>
#     <tr>
#       <td>80-90%</td>
#       <td>155740</td>
#     </tr>
#     <tr>
#       <td>90-100%</td>
#       <td>155741</td>
#     </tr>
#   </tbody>
# </table></div>
# 📊 Column: effective_tax_rate (n=1556820)
# <div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Summary Statistics</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Statistic</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>count</td>
#       <td>1556820.000000</td>
#     </tr>
#     <tr>
#       <td>mean</td>
#       <td>-1584.142644</td>
#     </tr>
#     <tr>
#       <td>std</td>
#       <td>1815550.187148</td>
#     </tr>
#     <tr>
#       <td>min</td>
#       <td>-2263290476.190476</td>
#     </tr>
#     <tr>
#       <td>0.1%</td>
#       <td>-26.008292</td>
#     </tr>
#     <tr>
#       <td>1%</td>
#       <td>-2.076302</td>
#     </tr>
#     <tr>
#       <td>5%</td>
#       <td>-0.266929</td>
#     </tr>
#     <tr>
#       <td>10%</td>
#       <td>-0.049229</td>
#     </tr>
#     <tr>
#       <td>20%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>30%</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>40%</td>
#       <td>0.059415</td>
#     </tr>
#     <tr>
#       <td>50%</td>
#       <td>0.148226</td>
#     </tr>
#     <tr>
#       <td>60%</td>
#       <td>0.203179</td>
#     </tr>
#     <tr>
#       <td>70%</td>
#       <td>0.250404</td>
#     </tr>
#     <tr>
#       <td>80%</td>
#       <td>0.304038</td>
#     </tr>
#     <tr>
#       <td>90%</td>
#       <td>0.392440</td>
#     </tr>
#     <tr>
#       <td>95%</td>
#       <td>0.600767</td>
#     </tr>
#     <tr>
#       <td>99%</td>
#       <td>2.298214</td>
#     </tr>
#     <tr>
#       <td>99.9%</td>
#       <td>26.641094</td>
#     </tr>
#     <tr>
#       <td>max</td>
#       <td>12403131.067961</td>
#     </tr>
#   </tbody>
# </table></div><div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Counts per Percentile Bucket (10 buckets)</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percentile Bucket</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0-10%</td>
#       <td>155684</td>
#     </tr>
#     <tr>
#       <td>10-20%</td>
#       <td>336816</td>
#     </tr>
#     <tr>
#       <td>20-30%</td>
#       <td>130228</td>
#     </tr>
#     <tr>
#       <td>30-40%</td>
#       <td>155682</td>
#     </tr>
#     <tr>
#       <td>40-50%</td>
#       <td>155687</td>
#     </tr>
#     <tr>
#       <td>50-60%</td>
#       <td>155679</td>
#     </tr>
#     <tr>
#       <td>60-70%</td>
#       <td>155681</td>
#     </tr>
#     <tr>
#       <td>70-80%</td>
#       <td>155681</td>
#     </tr>
#     <tr>
#       <td>80-90%</td>
#       <td>155682</td>
#     </tr>
#   </tbody>
# </table></div>
# 📊 Column: enterprise_value_multiple (n=1471242)
# <div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Summary Statistics</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Statistic</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>count</td>
#       <td>1471242.000000</td>
#     </tr>
#     <tr>
#       <td>mean</td>
#       <td>-37826.837472</td>
#     </tr>
#     <tr>
#       <td>std</td>
#       <td>27179300.354871</td>
#     </tr>
#     <tr>
#       <td>min</td>
#       <td>-9700800029.078014</td>
#     </tr>
#     <tr>
#       <td>0.1%</td>
#       <td>-225953.778409</td>
#     </tr>
#     <tr>
#       <td>1%</td>
#       <td>-3003.765372</td>
#     </tr>
#     <tr>
#       <td>5%</td>
#       <td>-235.870537</td>
#     </tr>
#     <tr>
#       <td>10%</td>
#       <td>-70.021770</td>
#     </tr>
#     <tr>
#       <td>20%</td>
#       <td>-10.006357</td>
#     </tr>
#     <tr>
#       <td>30%</td>
#       <td>0.068124</td>
#     </tr>
#     <tr>
#       <td>40%</td>
#       <td>14.192195</td>
#     </tr>
#     <tr>
#       <td>50%</td>
#       <td>23.910836</td>
#     </tr>
#     <tr>
#       <td>60%</td>
#       <td>34.513487</td>
#     </tr>
#     <tr>
#       <td>70%</td>
#       <td>48.385349</td>
#     </tr>
#     <tr>
#       <td>80%</td>
#       <td>71.879680</td>
#     </tr>
#     <tr>
#       <td>90%</td>
#       <td>136.609006</td>
#     </tr>
#     <tr>
#       <td>95%</td>
#       <td>272.262169</td>
#     </tr>
#     <tr>
#       <td>99%</td>
#       <td>1883.817112</td>
#     </tr>
#     <tr>
#       <td>99.9%</td>
#       <td>141961.855647</td>
#     </tr>
#     <tr>
#       <td>max</td>
#       <td>8238494200.000000</td>
#     </tr>
#   </tbody>
# </table></div><div style='display:inline-block; padding-right:30px; vertical-align:top;'><h3 style='margin:4px 0 8px 0;'>Counts per Percentile Bucket (10 buckets)</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percentile Bucket</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0-10%</td>
#       <td>147125</td>
#     </tr>
#     <tr>
#       <td>10-20%</td>
#       <td>147124</td>
#     </tr>
#     <tr>
#       <td>20-30%</td>
#       <td>147124</td>
#     </tr>
#     <tr>
#       <td>30-40%</td>
#       <td>147124</td>
#     </tr>
#     <tr>
#       <td>40-50%</td>
#       <td>147124</td>
#     </tr>
#     <tr>
#       <td>50-60%</td>
#       <td>147124</td>
#     </tr>
#     <tr>
#       <td>60-70%</td>
#       <td>147124</td>
#     </tr>
#     <tr>
#       <td>70-80%</td>
#       <td>147124</td>
#     </tr>
#     <tr>
#       <td>80-90%</td>
#       <td>147124</td>
#     </tr>
#     <tr>
#       <td>90-100%</td>
#       <td>147125</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# #### PIPELINE
# #### PIPELINE
# #### PIPELINE
# #### PIPELINE

# %%
# Out:
# ✅ Table clean.financial_metrics_perc recreated and populated.

# %%
import polars as pl
import numpy as np
import io
import pandas as pd
import psycopg2
from sqlalchemy import create_engine, text
from sqlalchemy.engine import Engine
from utils.utils import get_database_url, get_postgres_connection

# --------------------------
# Config & Setup
# --------------------------
DATABASE_URL = get_database_url()
target_table = "clean.financial_metrics_perc"
staging_schema = "stage"

# Metrics to process
metrics = [
    "gross_profit_margin",
    "ebit_margin",
    "ebitda_margin",
    "operating_profit_margin",
    "pretax_profit_margin",
    "continuous_operations_profit_margin",
    "net_profit_margin",
    "bottom_line_profit_margin",
    "current_ratio",
    "quick_ratio",
    "solvency_ratio",
    "cash_ratio",
    "receivables_turnover",
    "payables_turnover",
    "inventory_turnover",
    "fixed_asset_turnover",
    "asset_turnover",
    "working_capital_turnover_ratio",
    "price_to_earnings_ratio",
    "price_to_earnings_growth_ratio",
    "forward_price_to_earnings_growth_ratio",
    "price_to_book_ratio",
    "price_to_sales_ratio",
    "price_to_free_cash_flow_ratio",
    "price_to_operating_cash_flow_ratio",
    "price_to_fair_value",
    "debt_to_assets_ratio",
    "debt_to_equity_ratio",
    "debt_to_capital_ratio",
    "long_term_debt_to_capital_ratio",
    "financial_leverage_ratio",
    "debt_to_market_cap",
    "operating_cash_flow_ratio",
    "operating_cash_flow_sales_ratio",
    "free_cash_flow_operating_cash_flow_ratio",
    "debt_service_coverage_ratio",
    "interest_coverage_ratio",
    "short_term_operating_cash_flow_coverage_ratio",
    "operating_cash_flow_coverage_ratio",
    "capital_expenditure_coverage_ratio",
    "dividend_paid_and_capex_coverage_ratio",
    "dividend_payout_ratio",
    "dividend_yield",
    "dividend_yield_percentage",
    "dividend_per_share",
    "revenue_per_share",
    "net_income_per_share",
    "interest_debt_per_share",
    "cash_per_share",
    "book_value_per_share",
    "tangible_book_value_per_share",
    "shareholders_equity_per_share",
    "operating_cash_flow_per_share",
    "capex_per_share",
    "free_cash_flow_per_share",
    "net_income_per_ebt",
    "ebt_per_ebit",
    "effective_tax_rate",
    "enterprise_value_multiple"

]

# Columns always kept in final table
identity_columns = [
    'symbol',
    'date',
    'fiscal_year',
    'period',
    'reported_currency'
]

# --------------------------
# 1. Create/Populate Target Table
# --------------------------
print("📦 Recreating clean.financial_metrics_perc...")
engine: Engine = create_engine(DATABASE_URL)
with engine.begin() as conn:
    conn.execute(text("DROP TABLE IF EXISTS clean.financial_metrics_perc"))
    conn.execute(text(f"""
        CREATE TABLE clean.financial_metrics_perc AS
        SELECT {', '.join(identity_columns)}
        FROM raw.financial_metrics
        WHERE FALSE
    """))
    conn.execute(text(f"""
        INSERT INTO clean.financial_metrics_perc ({', '.join(identity_columns)})
        SELECT {', '.join(identity_columns)}
        FROM raw.financial_metrics
    """))
print("✅ clean.financial_metrics_perc initialized.")

# --------------------------
# 2. Load Full Raw Dataset
# --------------------------
def read_financial_metrics():
    conn = get_postgres_connection()
    cur = conn.cursor()
    buf = io.BytesIO()
    cur.copy_expert("COPY raw.financial_metrics TO STDOUT WITH CSV HEADER", buf)
    buf.seek(0)
    df = pl.read_csv(buf)
    cur.close()
    conn.close()
    return df

df_raw = read_financial_metrics()

# --------------------------
# 3. Percentile Processing + Insertion Loop
# --------------------------
percentile_levels = [0.01, 0.10, 0.20, 0.30, 0.40, 0.50, 0.60, 0.70, 0.80, 0.90, 0.99]
labels = ["<1%", "10%", "20%", "30%", "40%", "50%", "60%", "70%", "80%", "90%", "99%", ">99%"]

pg_conn = psycopg2.connect(DATABASE_URL.replace("postgresql+psycopg2", "postgresql"))
cursor = pg_conn.cursor()

for metric in metrics:
    perc_column = f"{metric}_perc"
    staging_table = f"tmp_{perc_column}"

    print(f"\n📊 Processing: {metric} → {perc_column}")

    # --------------------------
    # Create Percentile Buckets
    # --------------------------
    df_metric = df_raw.select(identity_columns + [metric]).filter(pl.col(metric).is_not_null())

    cutoffs = df_metric.select([
        pl.col(metric).quantile(q, "nearest").alias(f"p{int(q*100):02d}")
        for q in percentile_levels
    ]).row(0)

    bins = [-np.inf] + list(cutoffs) + [np.inf]
    bounds = list(zip(bins[:-1], bins[1:]))

    mapping_df = pl.DataFrame({
        "label": labels,
        "low": [bounds[i][0] for i in range(len(bounds))],
        "high": [bounds[i][1] for i in range(len(bounds))]
    }).with_columns([
        pl.when(pl.col("low") == float("-inf"))
        .then(pl.lit("-∞"))
        .otherwise(pl.col("low").round(2).cast(pl.Utf8))
        .alias("low_fmt"),

        pl.when(pl.col("high") == float("inf"))
        .then(pl.lit("+∞"))
        .otherwise(pl.col("high").round(2).cast(pl.Utf8))
        .alias("high_fmt")
    ]).with_columns([
        (pl.col("label") + " (" + pl.col("low_fmt") + " – " + pl.col("high_fmt") + ")")
        .alias("bracket_display")
    ])

    df_with_perc = (
        df_metric.lazy()
        .join(mapping_df.lazy(), how="cross")
        .filter(
            (pl.col(metric) >= pl.col("low")) & (pl.col(metric) < pl.col("high")) |
            ((pl.col("label") == ">99%") & (pl.col(metric) == pl.col("high")))
        )
        .select([
            "symbol", "date",
            pl.col("bracket_display").alias(perc_column)
        ])
        .collect()
    )

    # --------------------------
    # Write to Staging Table
    # --------------------------
    df_pd = df_with_perc.to_pandas()
    df_pd["date"] = pd.to_datetime(df_pd["date"])

    cursor.execute(f"SET search_path TO {staging_schema}")
    cursor.execute(f"DROP TABLE IF EXISTS {staging_table}")
    cursor.execute(f"""
        CREATE TABLE {staging_table} (
            symbol TEXT,
            date DATE,
            {perc_column} TEXT
        )
    """)
    pg_conn.commit()

    output = io.StringIO()
    df_pd.to_csv(output, sep="\t", index=False, header=False, na_rep='\\N')
    output.seek(0)

    cursor.copy_from(output, staging_table, sep="\t", null='\\N')
    pg_conn.commit()
    print("📥 Uploaded to staging table.")

    # --------------------------
    # Ensure Target Column Exists
    # --------------------------
    with engine.begin() as conn:
        conn.execute(text(f"""
            ALTER TABLE {target_table}
            ADD COLUMN IF NOT EXISTS {perc_column} VARCHAR(30);
        """))

    # --------------------------
    # Merge into Final Table
    # --------------------------
    with engine.begin() as conn:
        conn.execute(text(f"""
            UPDATE {target_table} t
            SET {perc_column} = s.{perc_column}
            FROM {staging_schema}.{staging_table} s
            WHERE t.symbol = s.symbol
              AND t.date = s.date::date
        """))

    print(f"✅ Column {perc_column} updated in target table")

    # --------------------------
    # Cleanup staging table
    # --------------------------

    cursor.execute(f"DROP TABLE IF EXISTS {staging_schema}.{staging_table}")
    pg_conn.commit()
    print(f"🧹 Dropped staging table: {staging_schema}.{staging_table}")
# Out:
# 📦 Recreating clean.financial_metrics_perc...
# ✅ clean.financial_metrics_perc initialized.
#
# 📊 Processing: gross_profit_margin → gross_profit_margin_perc
# 📥 Uploaded to staging table.
# ✅ Column gross_profit_margin_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_gross_profit_margin_perc
#
# 📊 Processing: ebit_margin → ebit_margin_perc
# 📥 Uploaded to staging table.
# ✅ Column ebit_margin_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_ebit_margin_perc
#
# 📊 Processing: ebitda_margin → ebitda_margin_perc
# 📥 Uploaded to staging table.
# ✅ Column ebitda_margin_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_ebitda_margin_perc
#
# 📊 Processing: operating_profit_margin → operating_profit_margin_perc
# 📥 Uploaded to staging table.
# ✅ Column operating_profit_margin_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_operating_profit_margin_perc
#
# 📊 Processing: pretax_profit_margin → pretax_profit_margin_perc
# 📥 Uploaded to staging table.
# ✅ Column pretax_profit_margin_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_pretax_profit_margin_perc
#
# 📊 Processing: continuous_operations_profit_margin → continuous_operations_profit_margin_perc
# 📥 Uploaded to staging table.
# ✅ Column continuous_operations_profit_margin_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_continuous_operations_profit_margin_perc
#
# 📊 Processing: net_profit_margin → net_profit_margin_perc
# 📥 Uploaded to staging table.
# ✅ Column net_profit_margin_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_net_profit_margin_perc
#
# 📊 Processing: bottom_line_profit_margin → bottom_line_profit_margin_perc
# 📥 Uploaded to staging table.
# ✅ Column bottom_line_profit_margin_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_bottom_line_profit_margin_perc
#
# 📊 Processing: current_ratio → current_ratio_perc
# 📥 Uploaded to staging table.
# ✅ Column current_ratio_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_current_ratio_perc
#
# 📊 Processing: quick_ratio → quick_ratio_perc
# 📥 Uploaded to staging table.
# ✅ Column quick_ratio_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_quick_ratio_perc
#
# 📊 Processing: solvency_ratio → solvency_ratio_perc
# 📥 Uploaded to staging table.
# ✅ Column solvency_ratio_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_solvency_ratio_perc
#
# 📊 Processing: cash_ratio → cash_ratio_perc
# 📥 Uploaded to staging table.
# ✅ Column cash_ratio_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_cash_ratio_perc
#
# 📊 Processing: receivables_turnover → receivables_turnover_perc
# 📥 Uploaded to staging table.
# ✅ Column receivables_turnover_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_receivables_turnover_perc
#
# 📊 Processing: payables_turnover → payables_turnover_perc
# 📥 Uploaded to staging table.
# ✅ Column payables_turnover_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_payables_turnover_perc
#
# 📊 Processing: inventory_turnover → inventory_turnover_perc
# 📥 Uploaded to staging table.
# ✅ Column inventory_turnover_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_inventory_turnover_perc
#
# 📊 Processing: fixed_asset_turnover → fixed_asset_turnover_perc
# 📥 Uploaded to staging table.
# ✅ Column fixed_asset_turnover_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_fixed_asset_turnover_perc
#
# 📊 Processing: asset_turnover → asset_turnover_perc
# 📥 Uploaded to staging table.
# ✅ Column asset_turnover_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_asset_turnover_perc
#
# 📊 Processing: working_capital_turnover_ratio → working_capital_turnover_ratio_perc
# 📥 Uploaded to staging table.
# ✅ Column working_capital_turnover_ratio_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_working_capital_turnover_ratio_perc
#
# 📊 Processing: price_to_earnings_ratio → price_to_earnings_ratio_perc
# 📥 Uploaded to staging table.
# ✅ Column price_to_earnings_ratio_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_price_to_earnings_ratio_perc
#
# 📊 Processing: price_to_earnings_growth_ratio → price_to_earnings_growth_ratio_perc
# 📥 Uploaded to staging table.
# ✅ Column price_to_earnings_growth_ratio_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_price_to_earnings_growth_ratio_perc
#
# 📊 Processing: forward_price_to_earnings_growth_ratio → forward_price_to_earnings_growth_ratio_perc
# 📥 Uploaded to staging table.
# ✅ Column forward_price_to_earnings_growth_ratio_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_forward_price_to_earnings_growth_ratio_perc
#
# 📊 Processing: price_to_book_ratio → price_to_book_ratio_perc
# 📥 Uploaded to staging table.
# ✅ Column price_to_book_ratio_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_price_to_book_ratio_perc
#
# 📊 Processing: price_to_sales_ratio → price_to_sales_ratio_perc
# 📥 Uploaded to staging table.
# ✅ Column price_to_sales_ratio_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_price_to_sales_ratio_perc
#
# 📊 Processing: price_to_free_cash_flow_ratio → price_to_free_cash_flow_ratio_perc
# 📥 Uploaded to staging table.
# ✅ Column price_to_free_cash_flow_ratio_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_price_to_free_cash_flow_ratio_perc
#
# 📊 Processing: price_to_operating_cash_flow_ratio → price_to_operating_cash_flow_ratio_perc
# 📥 Uploaded to staging table.
# ✅ Column price_to_operating_cash_flow_ratio_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_price_to_operating_cash_flow_ratio_perc
#
# 📊 Processing: price_to_fair_value → price_to_fair_value_perc
# 📥 Uploaded to staging table.
# ✅ Column price_to_fair_value_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_price_to_fair_value_perc
#
# 📊 Processing: debt_to_assets_ratio → debt_to_assets_ratio_perc
# 📥 Uploaded to staging table.
# ✅ Column debt_to_assets_ratio_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_debt_to_assets_ratio_perc
#
# 📊 Processing: debt_to_equity_ratio → debt_to_equity_ratio_perc
# 📥 Uploaded to staging table.
# ✅ Column debt_to_equity_ratio_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_debt_to_equity_ratio_perc
#
# 📊 Processing: debt_to_capital_ratio → debt_to_capital_ratio_perc
# 📥 Uploaded to staging table.
# ✅ Column debt_to_capital_ratio_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_debt_to_capital_ratio_perc
#
# 📊 Processing: long_term_debt_to_capital_ratio → long_term_debt_to_capital_ratio_perc
# 📥 Uploaded to staging table.
# ✅ Column long_term_debt_to_capital_ratio_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_long_term_debt_to_capital_ratio_perc
#
# 📊 Processing: financial_leverage_ratio → financial_leverage_ratio_perc
# 📥 Uploaded to staging table.
# ✅ Column financial_leverage_ratio_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_financial_leverage_ratio_perc
#
# 📊 Processing: debt_to_market_cap → debt_to_market_cap_perc
# 📥 Uploaded to staging table.
# ✅ Column debt_to_market_cap_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_debt_to_market_cap_perc
#
# 📊 Processing: operating_cash_flow_ratio → operating_cash_flow_ratio_perc
# 📥 Uploaded to staging table.
# ✅ Column operating_cash_flow_ratio_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_operating_cash_flow_ratio_perc
#
# 📊 Processing: operating_cash_flow_sales_ratio → operating_cash_flow_sales_ratio_perc
# 📥 Uploaded to staging table.
# ✅ Column operating_cash_flow_sales_ratio_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_operating_cash_flow_sales_ratio_perc
#
# 📊 Processing: free_cash_flow_operating_cash_flow_ratio → free_cash_flow_operating_cash_flow_ratio_perc
# 📥 Uploaded to staging table.
# ✅ Column free_cash_flow_operating_cash_flow_ratio_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_free_cash_flow_operating_cash_flow_ratio_perc
#
# 📊 Processing: debt_service_coverage_ratio → debt_service_coverage_ratio_perc
# 📥 Uploaded to staging table.
# ✅ Column debt_service_coverage_ratio_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_debt_service_coverage_ratio_perc
#
# 📊 Processing: interest_coverage_ratio → interest_coverage_ratio_perc
# 📥 Uploaded to staging table.
# ✅ Column interest_coverage_ratio_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_interest_coverage_ratio_perc
#
# 📊 Processing: short_term_operating_cash_flow_coverage_ratio → short_term_operating_cash_flow_coverage_ratio_perc
# 📥 Uploaded to staging table.
# ✅ Column short_term_operating_cash_flow_coverage_ratio_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_short_term_operating_cash_flow_coverage_ratio_perc
#
# 📊 Processing: operating_cash_flow_coverage_ratio → operating_cash_flow_coverage_ratio_perc
# 📥 Uploaded to staging table.
# ✅ Column operating_cash_flow_coverage_ratio_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_operating_cash_flow_coverage_ratio_perc
#
# 📊 Processing: capital_expenditure_coverage_ratio → capital_expenditure_coverage_ratio_perc
# 📥 Uploaded to staging table.
# ✅ Column capital_expenditure_coverage_ratio_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_capital_expenditure_coverage_ratio_perc
#
# 📊 Processing: dividend_paid_and_capex_coverage_ratio → dividend_paid_and_capex_coverage_ratio_perc
# 📥 Uploaded to staging table.
# ✅ Column dividend_paid_and_capex_coverage_ratio_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_dividend_paid_and_capex_coverage_ratio_perc
#
# 📊 Processing: dividend_payout_ratio → dividend_payout_ratio_perc
# 📥 Uploaded to staging table.
# ✅ Column dividend_payout_ratio_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_dividend_payout_ratio_perc
#
# 📊 Processing: dividend_yield → dividend_yield_perc
# 📥 Uploaded to staging table.
# ✅ Column dividend_yield_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_dividend_yield_perc
#
# 📊 Processing: dividend_yield_percentage → dividend_yield_percentage_perc
# 📥 Uploaded to staging table.
# ✅ Column dividend_yield_percentage_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_dividend_yield_percentage_perc
#
# 📊 Processing: dividend_per_share → dividend_per_share_perc
# 📥 Uploaded to staging table.
# ✅ Column dividend_per_share_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_dividend_per_share_perc
#
# 📊 Processing: revenue_per_share → revenue_per_share_perc
# 📥 Uploaded to staging table.
# ✅ Column revenue_per_share_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_revenue_per_share_perc
#
# 📊 Processing: net_income_per_share → net_income_per_share_perc
# 📥 Uploaded to staging table.
# ✅ Column net_income_per_share_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_net_income_per_share_perc
#
# 📊 Processing: interest_debt_per_share → interest_debt_per_share_perc
# 📥 Uploaded to staging table.
# ✅ Column interest_debt_per_share_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_interest_debt_per_share_perc
#
# 📊 Processing: cash_per_share → cash_per_share_perc
# 📥 Uploaded to staging table.
# ✅ Column cash_per_share_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_cash_per_share_perc
#
# 📊 Processing: book_value_per_share → book_value_per_share_perc
# 📥 Uploaded to staging table.
# ✅ Column book_value_per_share_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_book_value_per_share_perc
#
# 📊 Processing: tangible_book_value_per_share → tangible_book_value_per_share_perc
# 📥 Uploaded to staging table.
# ✅ Column tangible_book_value_per_share_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_tangible_book_value_per_share_perc
#
# 📊 Processing: shareholders_equity_per_share → shareholders_equity_per_share_perc
# 📥 Uploaded to staging table.
# ✅ Column shareholders_equity_per_share_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_shareholders_equity_per_share_perc
#
# 📊 Processing: operating_cash_flow_per_share → operating_cash_flow_per_share_perc
# 📥 Uploaded to staging table.
# ✅ Column operating_cash_flow_per_share_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_operating_cash_flow_per_share_perc
#
# 📊 Processing: capex_per_share → capex_per_share_perc
# 📥 Uploaded to staging table.
# ✅ Column capex_per_share_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_capex_per_share_perc
#
# 📊 Processing: free_cash_flow_per_share → free_cash_flow_per_share_perc
# 📥 Uploaded to staging table.
# ✅ Column free_cash_flow_per_share_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_free_cash_flow_per_share_perc
#
# 📊 Processing: net_income_per_ebt → net_income_per_ebt_perc
# 📥 Uploaded to staging table.
# ✅ Column net_income_per_ebt_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_net_income_per_ebt_perc
#
# 📊 Processing: ebt_per_ebit → ebt_per_ebit_perc
# 📥 Uploaded to staging table.
# ✅ Column ebt_per_ebit_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_ebt_per_ebit_perc
#
# 📊 Processing: effective_tax_rate → effective_tax_rate_perc
# 📥 Uploaded to staging table.
# ✅ Column effective_tax_rate_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_effective_tax_rate_perc
#
# 📊 Processing: enterprise_value_multiple → enterprise_value_multiple_perc
# 📥 Uploaded to staging table.
# ✅ Column enterprise_value_multiple_perc updated in target table
# 🧹 Dropped staging table: stage.tmp_enterprise_value_multiple_perc

# %%
import io
import numpy as np
import pandas as pd
import polars as pl
import psycopg2
from sqlalchemy import create_engine, text
from sqlalchemy.engine import Engine
from utils.utils import get_database_url, get_postgres_connection

# --------------------------
# Config
# --------------------------
DATABASE_URL = get_database_url()
engine: Engine = create_engine(DATABASE_URL)
target_table = "clean.financial_metrics_perc"
staging_schema = "stage"

identity_columns = ["symbol", "date", "fiscal_year", "period", "reported_currency"]

metrics = [
    "gross_profit_margin", "ebit_margin", "ebitda_margin",
    "operating_profit_margin", "pretax_profit_margin",
    "continuous_operations_profit_margin", "net_profit_margin",
    "bottom_line_profit_margin", "current_ratio", "quick_ratio",
    "solvency_ratio", "cash_ratio", "receivables_turnover",
    "payables_turnover", "inventory_turnover", "fixed_asset_turnover",
    "asset_turnover", "working_capital_turnover_ratio",
    "price_to_earnings_ratio", "price_to_earnings_growth_ratio",
    "forward_price_to_earnings_growth_ratio", "price_to_book_ratio",
    "price_to_sales_ratio", "price_to_free_cash_flow_ratio",
    "price_to_operating_cash_flow_ratio", "price_to_fair_value",
    "debt_to_assets_ratio", "debt_to_equity_ratio",
    "debt_to_capital_ratio", "long_term_debt_to_capital_ratio",
    "financial_leverage_ratio", "debt_to_market_cap",
    "operating_cash_flow_ratio", "operating_cash_flow_sales_ratio",
    "free_cash_flow_operating_cash_flow_ratio",
    "debt_service_coverage_ratio", "interest_coverage_ratio",
    "short_term_operating_cash_flow_coverage_ratio",
    "operating_cash_flow_coverage_ratio",
    "capital_expenditure_coverage_ratio",
    "dividend_paid_and_capex_coverage_ratio",
    "dividend_payout_ratio", "dividend_yield", "dividend_yield_percentage",
    "dividend_per_share", "revenue_per_share", "net_income_per_share",
    "interest_debt_per_share", "cash_per_share", "book_value_per_share",
    "tangible_book_value_per_share", "shareholders_equity_per_share",
    "operating_cash_flow_per_share", "capex_per_share",
    "free_cash_flow_per_share", "net_income_per_ebt", "ebt_per_ebit",
    "effective_tax_rate", "enterprise_value_multiple"
]

percentile_levels = [0.01,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,0.99]
labels = ["<1%","10%","20%","30%","40%","50%","60%","70%","80%","90%","99%",">99%"]

BATCH_SIZE = 10

# --------------------------
# Helpers
# --------------------------
def read_financial_metrics() -> pl.DataFrame:
    conn = get_postgres_connection()
    cur = conn.cursor()
    buf = io.BytesIO()
    cur.copy_expert("COPY raw.financial_metrics TO STDOUT WITH CSV HEADER", buf)
    buf.seek(0)
    df = pl.read_csv(buf, infer_schema_length=10000)
    cur.close()
    conn.close()
    return df.with_columns([
        pl.col("symbol").cast(pl.Utf8),
        pl.col("date").str.strptime(pl.Date, strict=False),
        pl.col("fiscal_year").cast(pl.Int64),
        pl.col("period").cast(pl.Utf8),
        pl.col("reported_currency").cast(pl.Utf8),
    ])

def bucketize_metric(df: pl.DataFrame, metric: str) -> pl.DataFrame:
    non_null = df.select(identity_columns + [metric]).filter(pl.col(metric).is_not_null())
    if non_null.height == 0:
        return pl.DataFrame({"symbol": [], "date": [], f"{metric}_perc": []})
    qs = non_null.select([
        pl.col(metric).quantile(q, "nearest").alias(f"p{int(q*100):02d}")
        for q in percentile_levels
    ]).row(0)
    bins = [-np.inf] + list(qs) + [np.inf]
    lows, highs = bins[:-1], bins[1:]
    def fmt(x): return "-∞" if x == float("-inf") else "+∞" if x == float("inf") else f"{x:.2f}"
    bracket_display = [f"{lab} ({fmt(lo)} – {fmt(hi)})" for lab, lo, hi in zip(labels, lows, highs)]
    mapping_df = pl.DataFrame({"_low": lows, "_high": highs, "_label": bracket_display})
    return (
        non_null.lazy()
        .join(mapping_df.lazy(), how="cross")
        .filter((pl.col(metric) >= pl.col("_low")) & (pl.col(metric) < pl.col("_high")))
        .select(["symbol","date",pl.col("_label").alias(f"{metric}_perc")])
        .collect()
    )

# --------------------------
# 1) Read raw + identities
# --------------------------
print("📥 Reading raw.financial_metrics …")
df_raw = read_financial_metrics()
df_base = df_raw.select(identity_columns).unique()

# --------------------------
# 2) Drop + recreate target
# --------------------------
print("🧨 Dropping + recreating target table …")
with engine.begin() as conn:
    conn.execute(text(f"DROP TABLE IF EXISTS {target_table}"))
    ddl = f"""
        CREATE TABLE {target_table} (
            symbol TEXT,
            date DATE,
            fiscal_year INTEGER,
            period TEXT,
            reported_currency TEXT
        ) WITH (fillfactor=100);
    """
    conn.execute(text(ddl))

# Insert identities once
pg_conn = psycopg2.connect(DATABASE_URL.replace("postgresql+psycopg2","postgresql"))
cur = pg_conn.cursor()
buf = io.StringIO()
df_base.to_pandas().to_csv(buf, sep="\t", index=False, header=False, na_rep="\\N")
buf.seek(0)
cols_sql = ", ".join([f'"{c}"' for c in identity_columns])
cur.copy_expert(f"COPY {target_table} ({cols_sql}) FROM STDIN WITH (FORMAT text, DELIMITER E'\\t', NULL '\\N')", buf)
pg_conn.commit()

# --------------------------
# 3) Process metrics in batches
# --------------------------
for i in range(0, len(metrics), BATCH_SIZE):
    batch = metrics[i:i+BATCH_SIZE]
    print(f"📊 Processing batch {i//BATCH_SIZE+1}: {batch}")

    batch_df = df_base
    for m in batch:
        df_m = bucketize_metric(df_raw, m)
        if df_m.height > 0:
            batch_df = batch_df.join(df_m, on=["symbol","date"], how="left")

    pdf = batch_df.to_pandas()
    pdf["date"] = pd.to_datetime(pdf["date"]).dt.date

    # Create staging
    staging = f"{staging_schema}.tmp_batch_{i}"
    cur.execute(f"DROP TABLE IF EXISTS {staging}")
    cur.execute(f'CREATE TABLE {staging} (symbol TEXT, date DATE, ' +
                ", ".join([f'"{m}_perc" TEXT' for m in batch]) + ")")
    pg_conn.commit()

    # COPY batch into staging
    buf = io.StringIO()
    pdf[["symbol","date"] + [f"{m}_perc" for m in batch]].to_csv(
        buf, sep="\t", index=False, header=False, na_rep="\\N"
    )
    buf.seek(0)
    cols = ["symbol","date"] + [f"{m}_perc" for m in batch]
    cols_sql = ", ".join([f'"{c}"' for c in cols])
    cur.copy_expert(f"COPY {staging} ({cols_sql}) FROM STDIN WITH (FORMAT text, DELIMITER E'\\t', NULL '\\N')", buf)
    pg_conn.commit()

    # Ensure target has the columns
    with engine.begin() as conn:
        for m in batch:
            conn.execute(text(f'ALTER TABLE {target_table} ADD COLUMN IF NOT EXISTS "{m}_perc" TEXT'))

        set_clause = ", ".join([f'"{m}_perc" = s."{m}_perc"' for m in batch])
        conn.execute(text(f"""
            UPDATE {target_table} t
            SET {set_clause}
            FROM {staging} s
            WHERE t.symbol = s.symbol
              AND t.date = s.date
        """))

    cur.execute(f"DROP TABLE IF EXISTS {staging}")
    pg_conn.commit()
    print(f"✅ Batch {i//BATCH_SIZE+1} merged.")

cur.close()
pg_conn.close()
print("🎉 Done — all batches merged into final table without overwriting.")
# Out:
# 📥 Reading raw.financial_metrics …
# 🧨 Dropping + recreating target table …
# 📊 Processing batch 1: ['gross_profit_margin', 'ebit_margin', 'ebitda_margin', 'operating_profit_margin', 'pretax_profit_margin', 'continuous_operations_profit_margin', 'net_profit_margin', 'bottom_line_profit_margin', 'current_ratio', 'quick_ratio']
# ✅ Batch 1 merged.
# 📊 Processing batch 2: ['solvency_ratio', 'cash_ratio', 'receivables_turnover', 'payables_turnover', 'inventory_turnover', 'fixed_asset_turnover', 'asset_turnover', 'working_capital_turnover_ratio', 'price_to_earnings_ratio', 'price_to_earnings_growth_ratio']
# ✅ Batch 2 merged.
# 📊 Processing batch 3: ['forward_price_to_earnings_growth_ratio', 'price_to_book_ratio', 'price_to_sales_ratio', 'price_to_free_cash_flow_ratio', 'price_to_operating_cash_flow_ratio', 'price_to_fair_value', 'debt_to_assets_ratio', 'debt_to_equity_ratio', 'debt_to_capital_ratio', 'long_term_debt_to_capital_ratio']
# ✅ Batch 3 merged.
# 📊 Processing batch 4: ['financial_leverage_ratio', 'debt_to_market_cap', 'operating_cash_flow_ratio', 'operating_cash_flow_sales_ratio', 'free_cash_flow_operating_cash_flow_ratio', 'debt_service_coverage_ratio', 'interest_coverage_ratio', 'short_term_operating_cash_flow_coverage_ratio', 'operating_cash_flow_coverage_ratio', 'capital_expenditure_coverage_ratio']
# ✅ Batch 4 merged.
# 📊 Processing batch 5: ['dividend_paid_and_capex_coverage_ratio', 'dividend_payout_ratio', 'dividend_yield', 'dividend_yield_percentage', 'dividend_per_share', 'revenue_per_share', 'net_income_per_share', 'interest_debt_per_share', 'cash_per_share', 'book_value_per_share']
# ✅ Batch 5 merged.
# 📊 Processing batch 6: ['tangible_book_value_per_share', 'shareholders_equity_per_share', 'operating_cash_flow_per_share', 'capex_per_share', 'free_cash_flow_per_share', 'net_income_per_ebt', 'ebt_per_ebit', 'effective_tax_rate', 'enterprise_value_multiple']
# ✅ Batch 6 merged.
# 🎉 Done — all batches merged into final table without overwriting.
